# %%
import pandas as pd

# %%
df = pd.read_csv('output.csv')

# %%
df
# Out:
#                                                     title      price  \
# 0       4 BHK Flat  for Sale in  Adore Presidential Wo...   ₹1.25 Cr
# 1       4 BHK Flat  for Sale in  Adore Presidential Wo...   ₹1.25 Cr
# 2       4 BHK Flat  for Sale in  BPTP Parkland Pride, ...   ₹1.18 Cr
# 3       1 BHK Flat  for Sale in  Amolik Sankalp, Secto...    ₹24 Lac
# 4       3 BHK Flat  for Sale in  Puri Amanvilas, Secto...   ₹1.15 Cr
# ...                                                   ...        ...
# 289523             4 BHK Flat for Sale in  Porur, Chennai   ₹1.79 Cr
# 289524           3 BHK Villa for Sale in Siruseri Chennai   ₹1.43 Cr
# 289525           2 BHK Flat for Sale in  Paranur, Chennai   ₹1.10 Cr
# 289526     2 BHK Flat for Sale in  Sithalapakkam, Chennai  ₹47.9 Lac
# 289527     3 BHK Flat for Sale in  Ekkatuthangal, Chennai   ₹2.15 Cr
#
#                         area              transaction  \
# 0        Super Area2925 sqft  TransactionNew Property
# 1        Super Area2925 sqft  TransactionNew Property
# 2        Super Area3150 sqft  TransactionNew Property
# 3         Super Area337 sqft  TransactionNew Property
# 4       Carpet Area1110 sqft  TransactionNew Property
# ...                      ...                      ...
# 289523   Super Area2001 sqft  TransactionNew Property
# 289524   Super Area1895 sqft  TransactionNew Property
# 289525   Super Area1248 sqft  TransactionNew Property
# 289526   Super Area1083 sqft  TransactionNew Property
# 289527   Super Area1467 sqft  TransactionNew Property
#
#                       furnishing                          society   bathroom  \
# 0          FurnishingUnfurnished  SocietyAdore Presidential World  Bathroom4
# 1          FurnishingUnfurnished  SocietyAdore Presidential World  Bathroom4
# 2          FurnishingUnfurnished       SocietyBPTP Parkland Pride  Bathroom4
# 3          FurnishingUnfurnished            SocietyAmolik Sankalp  Bathroom1
# 4       FurnishingSemi-Furnished            SocietyPuri Amanvilas  Bathroom2
# ...                          ...                              ...        ...
# 289523     FurnishingUnfurnished                              NaN  Bathroom3
# 289524     FurnishingUnfurnished                              NaN  Bathroom3
# 289525     FurnishingUnfurnished                              NaN  Bathroom1
# 289526     FurnishingUnfurnished                              NaN  Bathroom2
# 289527     FurnishingUnfurnished                              NaN  Bathroom3
#
#          balcony  usp_details numberOfRooms   latitude  longitude
# 0       Balcony4          NaN           NaN        NaN        NaN
# 1       Balcony4          NaN             4  28.404755  77.370169
# 2       Balcony4          NaN             4  28.369477  77.371623
# 3       Balcony1          NaN             1  28.404723  77.356094
# 4       Balcony2          NaN             3  28.417834  77.367077
# ...          ...          ...           ...        ...        ...
# 289523       NaN          NaN             4  13.047710  80.149220
# 289524       NaN          NaN             3  12.821477  80.204775
# 289525       NaN          NaN             2  12.705000  79.974890
# 289526       NaN          NaN             2  12.884633  80.187252
# 289527       NaN          NaN             3  13.023781  80.199446
#
# [289528 rows x 12 columns]

# %%
columns_to_remove = ['usp_details', 'society']  # Replace with the names of the columns you want to remove
df = df.drop(columns=columns_to_remove)

# %%
df
# Out:
#                                                     title      price  \
# 0       4 BHK Flat  for Sale in  Adore Presidential Wo...   ₹1.25 Cr
# 1       4 BHK Flat  for Sale in  Adore Presidential Wo...   ₹1.25 Cr
# 2       4 BHK Flat  for Sale in  BPTP Parkland Pride, ...   ₹1.18 Cr
# 3       1 BHK Flat  for Sale in  Amolik Sankalp, Secto...    ₹24 Lac
# 4       3 BHK Flat  for Sale in  Puri Amanvilas, Secto...   ₹1.15 Cr
# ...                                                   ...        ...
# 289523             4 BHK Flat for Sale in  Porur, Chennai   ₹1.79 Cr
# 289524           3 BHK Villa for Sale in Siruseri Chennai   ₹1.43 Cr
# 289525           2 BHK Flat for Sale in  Paranur, Chennai   ₹1.10 Cr
# 289526     2 BHK Flat for Sale in  Sithalapakkam, Chennai  ₹47.9 Lac
# 289527     3 BHK Flat for Sale in  Ekkatuthangal, Chennai   ₹2.15 Cr
#
#                         area              transaction  \
# 0        Super Area2925 sqft  TransactionNew Property
# 1        Super Area2925 sqft  TransactionNew Property
# 2        Super Area3150 sqft  TransactionNew Property
# 3         Super Area337 sqft  TransactionNew Property
# 4       Carpet Area1110 sqft  TransactionNew Property
# ...                      ...                      ...
# 289523   Super Area2001 sqft  TransactionNew Property
# 289524   Super Area1895 sqft  TransactionNew Property
# 289525   Super Area1248 sqft  TransactionNew Property
# 289526   Super Area1083 sqft  TransactionNew Property
# 289527   Super Area1467 sqft  TransactionNew Property
#
#                       furnishing   bathroom   balcony numberOfRooms  \
# 0          FurnishingUnfurnished  Bathroom4  Balcony4           NaN
# 1          FurnishingUnfurnished  Bathroom4  Balcony4             4
# 2          FurnishingUnfurnished  Bathroom4  Balcony4             4
# 3          FurnishingUnfurnished  Bathroom1  Balcony1             1
# 4       FurnishingSemi-Furnished  Bathroom2  Balcony2             3
# ...                          ...        ...       ...           ...
# 289523     FurnishingUnfurnished  Bathroom3       NaN             4
# 289524     FurnishingUnfurnished  Bathroom3       NaN             3
# 289525     FurnishingUnfurnished  Bathroom1       NaN             2
# 289526     FurnishingUnfurnished  Bathroom2       NaN             2
# 289527     FurnishingUnfurnished  Bathroom3       NaN             3
#
#          latitude  longitude
# 0             NaN        NaN
# 1       28.404755  77.370169
# 2       28.369477  77.371623
# 3       28.404723  77.356094
# 4       28.417834  77.367077
# ...           ...        ...
# 289523  13.047710  80.149220
# 289524  12.821477  80.204775
# 289525  12.705000  79.974890
# 289526  12.884633  80.187252
# 289527  13.023781  80.199446
#
# [289528 rows x 10 columns]

# %%
import pandas as pd
import re

def parse_price(price_str):
    """
    Attempts to convert price strings to a complete numeric value.
    
    Recognized formats:
      - '75L', '75 L', '75 lakh', '75lakh', '75 lac'  -> returns 75 * 100,000 = 7,500,000
      - '1.2Cr', '1.2 Cr', '1.2 crore'                 -> returns 1.2 * 10,000,000 = 12,000,000
      - 'Rs 75L', 'INR 1.2Cr'                          -> similar logic after removing currency symbols
      - If no unit is detected, returns the numeric part as-is.
    
    Unrecognized formats return None.
    """
    if not isinstance(price_str, str):
        return None
    
    # Convert to lowercase for uniformity
    price_str = price_str.lower().strip()
    
    # Remove common currency symbols or words (e.g., 'rs', 'inr')
    price_str = re.sub(r'\b(rs\.?|inr)\b', '', price_str)
    
    # Remove text within parentheses (e.g., "(negotiable)")
    price_str = re.sub(r'\(.*?\)', '', price_str)
    
    # Remove extra words that could interfere (e.g., 'onwards', 'approx')
    price_str = re.sub(r'\b(onwards|approx)\b', '', price_str)
    
    # Remove commas and extra spaces
    price_str = price_str.replace(',', '').strip()
    
    # Use regex to extract the first numeric part and an optional unit word.
    # This matches a number (possibly with commas or a decimal point) and
    # then an optional alphabetic unit.
    match = re.search(r'(\d[\d\.]*)\s*([a-z]+)?', price_str)
    if not match:
        return None

    numeric_part = match.group(1)
    try:
        value = float(numeric_part)
    except ValueError:
        return None

    unit = match.group(2) or ''

    # Check for unit keywords (for lakhs/lacs)
    if 'lakh' in unit or 'lac' in unit or unit == 'l':
        return value * 1e5  # 1 Lakh = 100,000
    # Check for unit keywords for crores
    elif 'cr' in unit or 'crore' in unit:
        return value * 1e7  # 1 Crore = 10,000,000
    else:
        # If no recognizable unit, assume the number is already complete.
        return value

# -------------------------------
# Example usage on your CSV file:
# -------------------------------

# Create a new column 'price_parsed' with the parsed values
df["price_parsed"] = df["price"].apply(parse_price)

# Print the number of rows where the price could not be parsed
print("Number of NaN (unparsed) prices:", df["price_parsed"].isna().sum())

# Save the updated DataFrame to a new CSV file
df.to_csv("output_parsed.csv", index=False)

print("Prices have been parsed and saved to 'output_parsed.csv'.")
# Out:
# Number of NaN (unparsed) prices: 4378
# Prices have been parsed and saved to 'output_parsed.csv'.

# %%
sdf = pd.read_csv('output_parsed.csv')
sdf
# Out:
#                                                     title      price  \
# 0       4 BHK Flat  for Sale in  Adore Presidential Wo...   ₹1.25 Cr
# 1       4 BHK Flat  for Sale in  Adore Presidential Wo...   ₹1.25 Cr
# 2       4 BHK Flat  for Sale in  BPTP Parkland Pride, ...   ₹1.18 Cr
# 3       1 BHK Flat  for Sale in  Amolik Sankalp, Secto...    ₹24 Lac
# 4       3 BHK Flat  for Sale in  Puri Amanvilas, Secto...   ₹1.15 Cr
# ...                                                   ...        ...
# 289523             4 BHK Flat for Sale in  Porur, Chennai   ₹1.79 Cr
# 289524           3 BHK Villa for Sale in Siruseri Chennai   ₹1.43 Cr
# 289525           2 BHK Flat for Sale in  Paranur, Chennai   ₹1.10 Cr
# 289526     2 BHK Flat for Sale in  Sithalapakkam, Chennai  ₹47.9 Lac
# 289527     3 BHK Flat for Sale in  Ekkatuthangal, Chennai   ₹2.15 Cr
#
#                         area              transaction  \
# 0        Super Area2925 sqft  TransactionNew Property
# 1        Super Area2925 sqft  TransactionNew Property
# 2        Super Area3150 sqft  TransactionNew Property
# 3         Super Area337 sqft  TransactionNew Property
# 4       Carpet Area1110 sqft  TransactionNew Property
# ...                      ...                      ...
# 289523   Super Area2001 sqft  TransactionNew Property
# 289524   Super Area1895 sqft  TransactionNew Property
# 289525   Super Area1248 sqft  TransactionNew Property
# 289526   Super Area1083 sqft  TransactionNew Property
# 289527   Super Area1467 sqft  TransactionNew Property
#
#                       furnishing   bathroom   balcony numberOfRooms  \
# 0          FurnishingUnfurnished  Bathroom4  Balcony4           NaN
# 1          FurnishingUnfurnished  Bathroom4  Balcony4             4
# 2          FurnishingUnfurnished  Bathroom4  Balcony4             4
# 3          FurnishingUnfurnished  Bathroom1  Balcony1             1
# 4       FurnishingSemi-Furnished  Bathroom2  Balcony2             3
# ...                          ...        ...       ...           ...
# 289523     FurnishingUnfurnished  Bathroom3       NaN             4
# 289524     FurnishingUnfurnished  Bathroom3       NaN             3
# 289525     FurnishingUnfurnished  Bathroom1       NaN             2
# 289526     FurnishingUnfurnished  Bathroom2       NaN             2
# 289527     FurnishingUnfurnished  Bathroom3       NaN             3
#
#          latitude  longitude  price_parsed
# 0             NaN        NaN    12500000.0
# 1       28.404755  77.370169    12500000.0
# 2       28.369477  77.371623    11800000.0
# 3       28.404723  77.356094     2400000.0
# 4       28.417834  77.367077    11500000.0
# ...           ...        ...           ...
# 289523  13.047710  80.149220    17900000.0
# 289524  12.821477  80.204775    14300000.0
# 289525  12.705000  79.974890    11000000.0
# 289526  12.884633  80.187252     4790000.0
# 289527  13.023781  80.199446    21500000.0
#
# [289528 rows x 11 columns]

# %%
import pandas as pd
import re

def parse_price(price_str):
    """
    Converts price strings like:
      - '₹76.5 Lac', '76.5 lac', '76.5 Lakh', '76.5L'
    into their complete numeric values:
      - For lakhs/lacs: multiply by 100,000
      - For crores: multiply by 10,000,000
    Returns None if the format is not recognized.
    """
    if not isinstance(price_str, str):
        return None

    # Convert to lowercase for uniformity and strip whitespace
    price_str = price_str.lower().strip()

    # Remove common currency symbols and words: remove '₹', 'rs', 'inr'
    price_str = price_str.replace('₹', '')
    price_str = re.sub(r'\b(rs\.?|inr)\b', '', price_str)

    # Remove commas and extra spaces
    price_str = price_str.replace(',', '').strip()
    
    # Remove any text in parentheses (if any)
    price_str = re.sub(r'\(.*?\)', '', price_str).strip()
    
    # Use regex to extract the first numeric part and an optional unit word.
    # It captures numbers like "76.5" and then the unit like "lac", "lakh", "cr", etc.
    match = re.search(r'(\d+(?:\.\d+)?)\s*([a-z]+)?', price_str)
    if not match:
        return None

    numeric_part = match.group(1)
    try:
        value = float(numeric_part)
    except ValueError:
        return None

    unit = match.group(2) or ''

    # Normalize unit spelling
    if unit in ['l', 'lac']:
        unit = 'lakh'
    
    # Multiply based on the unit
    if 'lakh' in unit:
        return value * 1e5  # 1 Lakh = 100,000
    elif 'cr' in unit or 'crore' in unit:
        return value * 1e7  # 1 Crore = 10,000,000
    else:
        # If no recognizable unit, return the numeric value as is.
        return value

# -------------------------------
# Example usage on your CSV file:
# -------------------------------


# Create a new column 'price_parsed' with the parsed values
df["price_parsed"] = df["price"].apply(parse_price)

# Print the number of rows where the price could not be parsed
print("Number of NaN (unparsed) prices:", df["price_parsed"].isna().sum())

# Save the updated DataFrame to a new CSV file
df.to_csv("output_parsed.csv", index=False)
print("Prices have been parsed and saved to 'output_parsed.csv'.")
# Out:
# Number of NaN (unparsed) prices: 4378
# Prices have been parsed and saved to 'output_parsed.csv'.

# %%
sdf = pd.read_csv('output_parsed.csv')
sdf
# Out:
#                                                     title      price  \
# 0       4 BHK Flat  for Sale in  Adore Presidential Wo...   ₹1.25 Cr
# 1       4 BHK Flat  for Sale in  Adore Presidential Wo...   ₹1.25 Cr
# 2       4 BHK Flat  for Sale in  BPTP Parkland Pride, ...   ₹1.18 Cr
# 3       1 BHK Flat  for Sale in  Amolik Sankalp, Secto...    ₹24 Lac
# 4       3 BHK Flat  for Sale in  Puri Amanvilas, Secto...   ₹1.15 Cr
# ...                                                   ...        ...
# 289523             4 BHK Flat for Sale in  Porur, Chennai   ₹1.79 Cr
# 289524           3 BHK Villa for Sale in Siruseri Chennai   ₹1.43 Cr
# 289525           2 BHK Flat for Sale in  Paranur, Chennai   ₹1.10 Cr
# 289526     2 BHK Flat for Sale in  Sithalapakkam, Chennai  ₹47.9 Lac
# 289527     3 BHK Flat for Sale in  Ekkatuthangal, Chennai   ₹2.15 Cr
#
#                         area              transaction  \
# 0        Super Area2925 sqft  TransactionNew Property
# 1        Super Area2925 sqft  TransactionNew Property
# 2        Super Area3150 sqft  TransactionNew Property
# 3         Super Area337 sqft  TransactionNew Property
# 4       Carpet Area1110 sqft  TransactionNew Property
# ...                      ...                      ...
# 289523   Super Area2001 sqft  TransactionNew Property
# 289524   Super Area1895 sqft  TransactionNew Property
# 289525   Super Area1248 sqft  TransactionNew Property
# 289526   Super Area1083 sqft  TransactionNew Property
# 289527   Super Area1467 sqft  TransactionNew Property
#
#                       furnishing   bathroom   balcony numberOfRooms  \
# 0          FurnishingUnfurnished  Bathroom4  Balcony4           NaN
# 1          FurnishingUnfurnished  Bathroom4  Balcony4             4
# 2          FurnishingUnfurnished  Bathroom4  Balcony4             4
# 3          FurnishingUnfurnished  Bathroom1  Balcony1             1
# 4       FurnishingSemi-Furnished  Bathroom2  Balcony2             3
# ...                          ...        ...       ...           ...
# 289523     FurnishingUnfurnished  Bathroom3       NaN             4
# 289524     FurnishingUnfurnished  Bathroom3       NaN             3
# 289525     FurnishingUnfurnished  Bathroom1       NaN             2
# 289526     FurnishingUnfurnished  Bathroom2       NaN             2
# 289527     FurnishingUnfurnished  Bathroom3       NaN             3
#
#          latitude  longitude  price_parsed
# 0             NaN        NaN    12500000.0
# 1       28.404755  77.370169    12500000.0
# 2       28.369477  77.371623    11800000.0
# 3       28.404723  77.356094     2400000.0
# 4       28.417834  77.367077    11500000.0
# ...           ...        ...           ...
# 289523  13.047710  80.149220    17900000.0
# 289524  12.821477  80.204775    14300000.0
# 289525  12.705000  79.974890    11000000.0
# 289526  12.884633  80.187252     4790000.0
# 289527  13.023781  80.199446    21500000.0
#
# [289528 rows x 11 columns]

# %%
df['price']
# Out:
# 0          ₹1.25 Cr
# 1          ₹1.25 Cr
# 2          ₹1.18 Cr
# 3           ₹24 Lac
# 4          ₹1.15 Cr
#             ...
# 289523     ₹1.79 Cr
# 289524     ₹1.43 Cr
# 289525     ₹1.10 Cr
# 289526    ₹47.9 Lac
# 289527     ₹2.15 Cr
# Name: price, Length: 289528, dtype: object

# %%
import pandas as pd
import re

def parse_price(price_str):
    """
    Parses price strings by first removing the ₹ symbol and converting values like:
      - '76.5 Lac' or '76.5lakh' -> 7,650,000
      - '1.13 Cr' or '1.13crore' -> 11,300,000
    into their complete numeric values.
    """
    if not isinstance(price_str, str):
        return None

    # Remove the rupee symbol
    price_str = price_str.replace("₹", "")
    
    # Convert to lowercase and strip whitespace
    price_str = price_str.lower().strip()
    
    # Remove common currency words if needed
    price_str = re.sub(r'\b(rs\.?|inr)\b', '', price_str)
    
    # Remove commas and extra spaces
    price_str = price_str.replace(',', '').strip()
    
    # Use regex to extract the numeric value and an optional unit
    match = re.search(r'(\d+(?:\.\d+)?)\s*([a-z]+)?', price_str)
    if not match:
        return None

    numeric_part = match.group(1)
    try:
        value = float(numeric_part)
    except ValueError:
        return None

    unit = match.group(2) or ''
    
    # Normalize unit spelling if necessary
    if unit in ['l', 'lac']:
        unit = 'lakh'
    
    # Convert based on unit
    if 'lakh' in unit:
        return value * 1e5  # 1 Lakh = 100,000
    elif 'cr' in unit or 'crore' in unit:
        return value * 1e7  # 1 Crore = 10,000,000
    else:
        return value

# Read CSV and remove ₹ before applying parsing
df["price"] = df["price"].str.replace("₹", "", regex=False)
df["price_parsed"] = df["price"].apply(parse_price)

print(df[["price", "price_parsed"]].head())
# Out:
#      price  price_parsed
# 0  1.25 Cr    12500000.0
# 1  1.25 Cr    12500000.0
# 2  1.18 Cr    11800000.0
# 3   24 Lac     2400000.0
# 4  1.15 Cr    11500000.0

# %%
df
# Out:
#                                                     title     price  \
# 0       4 BHK Flat  for Sale in  Adore Presidential Wo...   1.25 Cr
# 1       4 BHK Flat  for Sale in  Adore Presidential Wo...   1.25 Cr
# 2       4 BHK Flat  for Sale in  BPTP Parkland Pride, ...   1.18 Cr
# 3       1 BHK Flat  for Sale in  Amolik Sankalp, Secto...    24 Lac
# 4       3 BHK Flat  for Sale in  Puri Amanvilas, Secto...   1.15 Cr
# ...                                                   ...       ...
# 289523             4 BHK Flat for Sale in  Porur, Chennai   1.79 Cr
# 289524           3 BHK Villa for Sale in Siruseri Chennai   1.43 Cr
# 289525           2 BHK Flat for Sale in  Paranur, Chennai   1.10 Cr
# 289526     2 BHK Flat for Sale in  Sithalapakkam, Chennai  47.9 Lac
# 289527     3 BHK Flat for Sale in  Ekkatuthangal, Chennai   2.15 Cr
#
#                         area              transaction  \
# 0        Super Area2925 sqft  TransactionNew Property
# 1        Super Area2925 sqft  TransactionNew Property
# 2        Super Area3150 sqft  TransactionNew Property
# 3         Super Area337 sqft  TransactionNew Property
# 4       Carpet Area1110 sqft  TransactionNew Property
# ...                      ...                      ...
# 289523   Super Area2001 sqft  TransactionNew Property
# 289524   Super Area1895 sqft  TransactionNew Property
# 289525   Super Area1248 sqft  TransactionNew Property
# 289526   Super Area1083 sqft  TransactionNew Property
# 289527   Super Area1467 sqft  TransactionNew Property
#
#                       furnishing   bathroom   balcony numberOfRooms  \
# 0          FurnishingUnfurnished  Bathroom4  Balcony4           NaN
# 1          FurnishingUnfurnished  Bathroom4  Balcony4             4
# 2          FurnishingUnfurnished  Bathroom4  Balcony4             4
# 3          FurnishingUnfurnished  Bathroom1  Balcony1             1
# 4       FurnishingSemi-Furnished  Bathroom2  Balcony2             3
# ...                          ...        ...       ...           ...
# 289523     FurnishingUnfurnished  Bathroom3       NaN             4
# 289524     FurnishingUnfurnished  Bathroom3       NaN             3
# 289525     FurnishingUnfurnished  Bathroom1       NaN             2
# 289526     FurnishingUnfurnished  Bathroom2       NaN             2
# 289527     FurnishingUnfurnished  Bathroom3       NaN             3
#
#          latitude  longitude  price_parsed
# 0             NaN        NaN    12500000.0
# 1       28.404755  77.370169    12500000.0
# 2       28.369477  77.371623    11800000.0
# 3       28.404723  77.356094     2400000.0
# 4       28.417834  77.367077    11500000.0
# ...           ...        ...           ...
# 289523  13.047710  80.149220    17900000.0
# 289524  12.821477  80.204775    14300000.0
# 289525  12.705000  79.974890    11000000.0
# 289526  12.884633  80.187252     4790000.0
# 289527  13.023781  80.199446    21500000.0
#
# [289528 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289528 entries, 0 to 289527
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   title          289528 non-null  object
#  1   price          289527 non-null  object
#  2   area           287872 non-null  object
#  3   transaction    289182 non-null  object
#  4   furnishing     284095 non-null  object
#  5   bathroom       286241 non-null  object
#  6   balcony        200398 non-null  object
#  7   numberOfRooms  278067 non-null  object
#  8   latitude       272880 non-null  float64
#  9   longitude      272880 non-null  float64
#  10  price_parsed   285150 non-null  float64
# dtypes: float64(3), object(8)
# memory usage: 24.3+ MB

# %%
# Replace the 'price' column with the parsed values from 'price_parsed'
df["price"] = df["price_parsed"]

# Optionally, drop the 'price_parsed' column if it's no longer needed
df.drop(columns=["price_parsed"], inplace=True)

# Verify the change
print(df.head())
# Out:
#                                                title       price  \
# 0  4 BHK Flat  for Sale in  Adore Presidential Wo...  12500000.0
# 1  4 BHK Flat  for Sale in  Adore Presidential Wo...  12500000.0
# 2  4 BHK Flat  for Sale in  BPTP Parkland Pride, ...  11800000.0
# 3  1 BHK Flat  for Sale in  Amolik Sankalp, Secto...   2400000.0
# 4  3 BHK Flat  for Sale in  Puri Amanvilas, Secto...  11500000.0
#
#                    area              transaction                furnishing  \
# 0   Super Area2925 sqft  TransactionNew Property     FurnishingUnfurnished
# 1   Super Area2925 sqft  TransactionNew Property     FurnishingUnfurnished
# 2   Super Area3150 sqft  TransactionNew Property     FurnishingUnfurnished
# 3    Super Area337 sqft  TransactionNew Property     FurnishingUnfurnished
# 4  Carpet Area1110 sqft  TransactionNew Property  FurnishingSemi-Furnished
#
#     bathroom   balcony numberOfRooms   latitude  longitude
# 0  Bathroom4  Balcony4           NaN        NaN        NaN
# 1  Bathroom4  Balcony4             4  28.404755  77.370169
# 2  Bathroom4  Balcony4             4  28.369477  77.371623
# 3  Bathroom1  Balcony1             1  28.404723  77.356094
# 4  Bathroom2  Balcony2             3  28.417834  77.367077

# %%
df
# Out:
#                                                     title       price  \
# 0       4 BHK Flat  for Sale in  Adore Presidential Wo...  12500000.0
# 1       4 BHK Flat  for Sale in  Adore Presidential Wo...  12500000.0
# 2       4 BHK Flat  for Sale in  BPTP Parkland Pride, ...  11800000.0
# 3       1 BHK Flat  for Sale in  Amolik Sankalp, Secto...   2400000.0
# 4       3 BHK Flat  for Sale in  Puri Amanvilas, Secto...  11500000.0
# ...                                                   ...         ...
# 289523             4 BHK Flat for Sale in  Porur, Chennai  17900000.0
# 289524           3 BHK Villa for Sale in Siruseri Chennai  14300000.0
# 289525           2 BHK Flat for Sale in  Paranur, Chennai  11000000.0
# 289526     2 BHK Flat for Sale in  Sithalapakkam, Chennai   4790000.0
# 289527     3 BHK Flat for Sale in  Ekkatuthangal, Chennai  21500000.0
#
#                         area              transaction  \
# 0        Super Area2925 sqft  TransactionNew Property
# 1        Super Area2925 sqft  TransactionNew Property
# 2        Super Area3150 sqft  TransactionNew Property
# 3         Super Area337 sqft  TransactionNew Property
# 4       Carpet Area1110 sqft  TransactionNew Property
# ...                      ...                      ...
# 289523   Super Area2001 sqft  TransactionNew Property
# 289524   Super Area1895 sqft  TransactionNew Property
# 289525   Super Area1248 sqft  TransactionNew Property
# 289526   Super Area1083 sqft  TransactionNew Property
# 289527   Super Area1467 sqft  TransactionNew Property
#
#                       furnishing   bathroom   balcony numberOfRooms  \
# 0          FurnishingUnfurnished  Bathroom4  Balcony4           NaN
# 1          FurnishingUnfurnished  Bathroom4  Balcony4             4
# 2          FurnishingUnfurnished  Bathroom4  Balcony4             4
# 3          FurnishingUnfurnished  Bathroom1  Balcony1             1
# 4       FurnishingSemi-Furnished  Bathroom2  Balcony2             3
# ...                          ...        ...       ...           ...
# 289523     FurnishingUnfurnished  Bathroom3       NaN             4
# 289524     FurnishingUnfurnished  Bathroom3       NaN             3
# 289525     FurnishingUnfurnished  Bathroom1       NaN             2
# 289526     FurnishingUnfurnished  Bathroom2       NaN             2
# 289527     FurnishingUnfurnished  Bathroom3       NaN             3
#
#          latitude  longitude
# 0             NaN        NaN
# 1       28.404755  77.370169
# 2       28.369477  77.371623
# 3       28.404723  77.356094
# 4       28.417834  77.367077
# ...           ...        ...
# 289523  13.047710  80.149220
# 289524  12.821477  80.204775
# 289525  12.705000  79.974890
# 289526  12.884633  80.187252
# 289527  13.023781  80.199446
#
# [289528 rows x 10 columns]

# %%
df['area']
# Out:
# 0          Super Area2925 sqft
# 1          Super Area2925 sqft
# 2          Super Area3150 sqft
# 3           Super Area337 sqft
# 4         Carpet Area1110 sqft
#                   ...
# 289523     Super Area2001 sqft
# 289524     Super Area1895 sqft
# 289525     Super Area1248 sqft
# 289526     Super Area1083 sqft
# 289527     Super Area1467 sqft
# Name: area, Length: 289528, dtype: object

# %%
import pandas as pd
import re

def extract_area(area_str):
    """
    Extracts the numeric part from a string like 'Super Area1500 sqft'.
    """
    match = re.search(r'(\d+)', area_str)
    if match:
        return int(match.group(1))  # Use int() if you expect whole numbers
    return None

# Assuming df is your DataFrame
df['area'] = df['area'].apply(extract_area)

# Check the first few values
print(df['area'].head())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 14
#      11     return None
#      13 # Assuming df is your DataFrame
# ---> 14 df['area'] = df['area'].apply(extract_area)
#      16 # Check the first few values
#      17 print(df['area'].head())
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[58], line 8, in extract_area(area_str)
#       4 def extract_area(area_str):
#       5     """
#       6     Extracts the numeric part from a string like 'Super Area1500 sqft'.
#       7     """
# ----> 8     match = re.search(r'(\d+)', area_str)
#       9     if match:
#      10         return int(match.group(1))  # Use int() if you expect whole numbers
#
# File c:\Users\ASUS\anaconda3\Lib\re\__init__.py:177, in search(pattern, string, flags)
#     174 def search(pattern, string, flags=0):
#     175     """Scan through string looking for a match to the pattern, returning
#     176     a Match object, or None if no match was found."""
# --> 177     return _compile(pattern, flags).search(string)
#
# TypeError: expected string or bytes-like object, got 'float'

# %%
import pandas as pd
import re

def extract_area(area_val):
    # If the value is NaN, return None
    if pd.isna(area_val):
        return None
    
    # Convert the value to a string
    s = str(area_val)
    # Search for one or more digits in the string
    match = re.search(r'(\d+)', s)
    if match:
        return int(match.group(1))
    return None

# Assuming df is your DataFrame
df['area'] = df['area'].apply(extract_area)

# Check the first few values
print(df['area'].head())
# Out:
# 0    2925.0
# 1    2925.0
# 2    3150.0
# 3     337.0
# 4    1110.0
# Name: area, dtype: float64

# %%
df
# Out:
#                                                     title       price    area  \
# 0       4 BHK Flat  for Sale in  Adore Presidential Wo...  12500000.0  2925.0
# 1       4 BHK Flat  for Sale in  Adore Presidential Wo...  12500000.0  2925.0
# 2       4 BHK Flat  for Sale in  BPTP Parkland Pride, ...  11800000.0  3150.0
# 3       1 BHK Flat  for Sale in  Amolik Sankalp, Secto...   2400000.0   337.0
# 4       3 BHK Flat  for Sale in  Puri Amanvilas, Secto...  11500000.0  1110.0
# ...                                                   ...         ...     ...
# 289523             4 BHK Flat for Sale in  Porur, Chennai  17900000.0  2001.0
# 289524           3 BHK Villa for Sale in Siruseri Chennai  14300000.0  1895.0
# 289525           2 BHK Flat for Sale in  Paranur, Chennai  11000000.0  1248.0
# 289526     2 BHK Flat for Sale in  Sithalapakkam, Chennai   4790000.0  1083.0
# 289527     3 BHK Flat for Sale in  Ekkatuthangal, Chennai  21500000.0  1467.0
#
#                     transaction                furnishing   bathroom  \
# 0       TransactionNew Property     FurnishingUnfurnished  Bathroom4
# 1       TransactionNew Property     FurnishingUnfurnished  Bathroom4
# 2       TransactionNew Property     FurnishingUnfurnished  Bathroom4
# 3       TransactionNew Property     FurnishingUnfurnished  Bathroom1
# 4       TransactionNew Property  FurnishingSemi-Furnished  Bathroom2
# ...                         ...                       ...        ...
# 289523  TransactionNew Property     FurnishingUnfurnished  Bathroom3
# 289524  TransactionNew Property     FurnishingUnfurnished  Bathroom3
# 289525  TransactionNew Property     FurnishingUnfurnished  Bathroom1
# 289526  TransactionNew Property     FurnishingUnfurnished  Bathroom2
# 289527  TransactionNew Property     FurnishingUnfurnished  Bathroom3
#
#          balcony numberOfRooms   latitude  longitude
# 0       Balcony4           NaN        NaN        NaN
# 1       Balcony4             4  28.404755  77.370169
# 2       Balcony4             4  28.369477  77.371623
# 3       Balcony1             1  28.404723  77.356094
# 4       Balcony2             3  28.417834  77.367077
# ...          ...           ...        ...        ...
# 289523       NaN             4  13.047710  80.149220
# 289524       NaN             3  12.821477  80.204775
# 289525       NaN             2  12.705000  79.974890
# 289526       NaN             2  12.884633  80.187252
# 289527       NaN             3  13.023781  80.199446
#
# [289528 rows x 10 columns]

# %%
df['transaction']
# Out:
# 0         TransactionNew Property
# 1         TransactionNew Property
# 2         TransactionNew Property
# 3         TransactionNew Property
# 4         TransactionNew Property
#                    ...
# 289523    TransactionNew Property
# 289524    TransactionNew Property
# 289525    TransactionNew Property
# 289526    TransactionNew Property
# 289527    TransactionNew Property
# Name: transaction, Length: 289528, dtype: object

# %%
def convert_transaction(val):
    # Convert to lowercase and remove extra spaces
    val = val.lower().strip()
    if "new" in val:
        return 1
    elif "resale" in val:
        return 0
    return None  # For unexpected values

df["transaction_numeric"] = df["transaction"].apply(convert_transaction)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 10
#       7         return 0
#       8     return None  # For unexpected values
# ---> 10 df["transaction_numeric"] = df["transaction"].apply(convert_transaction)
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[63], line 3, in convert_transaction(val)
#       1 def convert_transaction(val):
#       2     # Convert to lowercase and remove extra spaces
# ----> 3     val = val.lower().strip()
#       4     if "new" in val:
#       5         return 1
#
# AttributeError: 'float' object has no attribute 'lower'

# %%
import pandas as pd

def convert_transaction(val):
    # Check if the value is missing or not a string
    if pd.isna(val):
        return None
    # Convert the value to string before processing
    s = str(val).lower().strip()
    if "new" in s:
        return 1
    elif "resale" in s:
        return 0
    else:
        return None  # For unexpected values

# Example usage on your DataFrame
df["transaction_numeric"] = df["transaction"].apply(convert_transaction)
print(df["transaction_numeric"].head())
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# Name: transaction_numeric, dtype: float64

# %%
df
# Out:
#                                                     title       price    area  \
# 0       4 BHK Flat  for Sale in  Adore Presidential Wo...  12500000.0  2925.0
# 1       4 BHK Flat  for Sale in  Adore Presidential Wo...  12500000.0  2925.0
# 2       4 BHK Flat  for Sale in  BPTP Parkland Pride, ...  11800000.0  3150.0
# 3       1 BHK Flat  for Sale in  Amolik Sankalp, Secto...   2400000.0   337.0
# 4       3 BHK Flat  for Sale in  Puri Amanvilas, Secto...  11500000.0  1110.0
# ...                                                   ...         ...     ...
# 289523             4 BHK Flat for Sale in  Porur, Chennai  17900000.0  2001.0
# 289524           3 BHK Villa for Sale in Siruseri Chennai  14300000.0  1895.0
# 289525           2 BHK Flat for Sale in  Paranur, Chennai  11000000.0  1248.0
# 289526     2 BHK Flat for Sale in  Sithalapakkam, Chennai   4790000.0  1083.0
# 289527     3 BHK Flat for Sale in  Ekkatuthangal, Chennai  21500000.0  1467.0
#
#                     transaction                furnishing   bathroom  \
# 0       TransactionNew Property     FurnishingUnfurnished  Bathroom4
# 1       TransactionNew Property     FurnishingUnfurnished  Bathroom4
# 2       TransactionNew Property     FurnishingUnfurnished  Bathroom4
# 3       TransactionNew Property     FurnishingUnfurnished  Bathroom1
# 4       TransactionNew Property  FurnishingSemi-Furnished  Bathroom2
# ...                         ...                       ...        ...
# 289523  TransactionNew Property     FurnishingUnfurnished  Bathroom3
# 289524  TransactionNew Property     FurnishingUnfurnished  Bathroom3
# 289525  TransactionNew Property     FurnishingUnfurnished  Bathroom1
# 289526  TransactionNew Property     FurnishingUnfurnished  Bathroom2
# 289527  TransactionNew Property     FurnishingUnfurnished  Bathroom3
#
#          balcony numberOfRooms   latitude  longitude  transaction_numeric
# 0       Balcony4           NaN        NaN        NaN                  1.0
# 1       Balcony4             4  28.404755  77.370169                  1.0
# 2       Balcony4             4  28.369477  77.371623                  1.0
# 3       Balcony1             1  28.404723  77.356094                  1.0
# 4       Balcony2             3  28.417834  77.367077                  1.0
# ...          ...           ...        ...        ...                  ...
# 289523       NaN             4  13.047710  80.149220                  1.0
# 289524       NaN             3  12.821477  80.204775                  1.0
# 289525       NaN             2  12.705000  79.974890                  1.0
# 289526       NaN             2  12.884633  80.187252                  1.0
# 289527       NaN             3  13.023781  80.199446                  1.0
#
# [289528 rows x 11 columns]

# %%
import pandas as pd

def convert_transaction(val):
    # Check if the value is missing; if so, return None
    if pd.isna(val):
        return None
    # Convert the value to a string and normalize
    s = str(val).lower().strip()
    # Map based on keywords
    if "new" in s:
        return 1
    elif "resale" in s:
        return 0
    else:
        return None  # For any unexpected values

# Assuming df is your DataFrame, apply the conversion and replace the column.
df["transaction"] = df["transaction"].apply(convert_transaction)

# Verify the results
print(df["transaction"].head())
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# Name: transaction, dtype: float64

# %%
df
# Out:
#                                                     title       price    area  \
# 0       4 BHK Flat  for Sale in  Adore Presidential Wo...  12500000.0  2925.0
# 1       4 BHK Flat  for Sale in  Adore Presidential Wo...  12500000.0  2925.0
# 2       4 BHK Flat  for Sale in  BPTP Parkland Pride, ...  11800000.0  3150.0
# 3       1 BHK Flat  for Sale in  Amolik Sankalp, Secto...   2400000.0   337.0
# 4       3 BHK Flat  for Sale in  Puri Amanvilas, Secto...  11500000.0  1110.0
# ...                                                   ...         ...     ...
# 289523             4 BHK Flat for Sale in  Porur, Chennai  17900000.0  2001.0
# 289524           3 BHK Villa for Sale in Siruseri Chennai  14300000.0  1895.0
# 289525           2 BHK Flat for Sale in  Paranur, Chennai  11000000.0  1248.0
# 289526     2 BHK Flat for Sale in  Sithalapakkam, Chennai   4790000.0  1083.0
# 289527     3 BHK Flat for Sale in  Ekkatuthangal, Chennai  21500000.0  1467.0
#
#         transaction                furnishing   bathroom   balcony  \
# 0               1.0     FurnishingUnfurnished  Bathroom4  Balcony4
# 1               1.0     FurnishingUnfurnished  Bathroom4  Balcony4
# 2               1.0     FurnishingUnfurnished  Bathroom4  Balcony4
# 3               1.0     FurnishingUnfurnished  Bathroom1  Balcony1
# 4               1.0  FurnishingSemi-Furnished  Bathroom2  Balcony2
# ...             ...                       ...        ...       ...
# 289523          1.0     FurnishingUnfurnished  Bathroom3       NaN
# 289524          1.0     FurnishingUnfurnished  Bathroom3       NaN
# 289525          1.0     FurnishingUnfurnished  Bathroom1       NaN
# 289526          1.0     FurnishingUnfurnished  Bathroom2       NaN
# 289527          1.0     FurnishingUnfurnished  Bathroom3       NaN
#
#        numberOfRooms   latitude  longitude  transaction_numeric
# 0                NaN        NaN        NaN                  1.0
# 1                  4  28.404755  77.370169                  1.0
# 2                  4  28.369477  77.371623                  1.0
# 3                  1  28.404723  77.356094                  1.0
# 4                  3  28.417834  77.367077                  1.0
# ...              ...        ...        ...                  ...
# 289523             4  13.047710  80.149220                  1.0
# 289524             3  12.821477  80.204775                  1.0
# 289525             2  12.705000  79.974890                  1.0
# 289526             2  12.884633  80.187252                  1.0
# 289527             3  13.023781  80.199446                  1.0
#
# [289528 rows x 11 columns]

# %%
df.drop("transaction_numeric", axis=1, inplace=True)

# %%
df
# Out:
#                                                     title       price    area  \
# 0       4 BHK Flat  for Sale in  Adore Presidential Wo...  12500000.0  2925.0
# 1       4 BHK Flat  for Sale in  Adore Presidential Wo...  12500000.0  2925.0
# 2       4 BHK Flat  for Sale in  BPTP Parkland Pride, ...  11800000.0  3150.0
# 3       1 BHK Flat  for Sale in  Amolik Sankalp, Secto...   2400000.0   337.0
# 4       3 BHK Flat  for Sale in  Puri Amanvilas, Secto...  11500000.0  1110.0
# ...                                                   ...         ...     ...
# 289523             4 BHK Flat for Sale in  Porur, Chennai  17900000.0  2001.0
# 289524           3 BHK Villa for Sale in Siruseri Chennai  14300000.0  1895.0
# 289525           2 BHK Flat for Sale in  Paranur, Chennai  11000000.0  1248.0
# 289526     2 BHK Flat for Sale in  Sithalapakkam, Chennai   4790000.0  1083.0
# 289527     3 BHK Flat for Sale in  Ekkatuthangal, Chennai  21500000.0  1467.0
#
#         transaction                furnishing   bathroom   balcony  \
# 0               1.0     FurnishingUnfurnished  Bathroom4  Balcony4
# 1               1.0     FurnishingUnfurnished  Bathroom4  Balcony4
# 2               1.0     FurnishingUnfurnished  Bathroom4  Balcony4
# 3               1.0     FurnishingUnfurnished  Bathroom1  Balcony1
# 4               1.0  FurnishingSemi-Furnished  Bathroom2  Balcony2
# ...             ...                       ...        ...       ...
# 289523          1.0     FurnishingUnfurnished  Bathroom3       NaN
# 289524          1.0     FurnishingUnfurnished  Bathroom3       NaN
# 289525          1.0     FurnishingUnfurnished  Bathroom1       NaN
# 289526          1.0     FurnishingUnfurnished  Bathroom2       NaN
# 289527          1.0     FurnishingUnfurnished  Bathroom3       NaN
#
#        numberOfRooms   latitude  longitude
# 0                NaN        NaN        NaN
# 1                  4  28.404755  77.370169
# 2                  4  28.369477  77.371623
# 3                  1  28.404723  77.356094
# 4                  3  28.417834  77.367077
# ...              ...        ...        ...
# 289523             4  13.047710  80.149220
# 289524             3  12.821477  80.204775
# 289525             2  12.705000  79.974890
# 289526             2  12.884633  80.187252
# 289527             3  13.023781  80.199446
#
# [289528 rows x 10 columns]

# %%
df["transaction"] = df["transaction"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df["transaction"] = df["transaction"].astype(int)
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:101, in _astype_nansafe(arr, dtype, copy, skipna)
#      96     return lib.ensure_string_array(
#      97         arr, skipna=skipna, convert_na_value=False
#      98     ).reshape(shape)
#     100 elif np.issubdtype(arr.dtype, np.floating) and dtype.kind in "iu":
# --> 101     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     103 elif arr.dtype == object:
#     104     # if we have a datetime/timedelta array of objects
#     105     # then coerce to datetime64[ns] and use DatetimeArray.astype
#     107     if lib.is_np_dtype(dtype, "M"):
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:145, in _astype_float_to_int_nansafe(values, dtype, copy)
#     141 """
#     142 astype with a check preventing converting NaN to an meaningless integer value.
#     143 """
#     144 if not np.isfinite(values).all():
# --> 145     raise IntCastingNaNError(
#     146         "Cannot convert non-finite values (NA or inf) to integer"
#     147     )
#     148 if dtype.kind == "u":
#     149     # GH#45151
#     150     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
df["transaction"] = df["transaction"].astype("Int64")

# %%
df
# Out:
#                                                     title       price    area  \
# 0       4 BHK Flat  for Sale in  Adore Presidential Wo...  12500000.0  2925.0
# 1       4 BHK Flat  for Sale in  Adore Presidential Wo...  12500000.0  2925.0
# 2       4 BHK Flat  for Sale in  BPTP Parkland Pride, ...  11800000.0  3150.0
# 3       1 BHK Flat  for Sale in  Amolik Sankalp, Secto...   2400000.0   337.0
# 4       3 BHK Flat  for Sale in  Puri Amanvilas, Secto...  11500000.0  1110.0
# ...                                                   ...         ...     ...
# 289523             4 BHK Flat for Sale in  Porur, Chennai  17900000.0  2001.0
# 289524           3 BHK Villa for Sale in Siruseri Chennai  14300000.0  1895.0
# 289525           2 BHK Flat for Sale in  Paranur, Chennai  11000000.0  1248.0
# 289526     2 BHK Flat for Sale in  Sithalapakkam, Chennai   4790000.0  1083.0
# 289527     3 BHK Flat for Sale in  Ekkatuthangal, Chennai  21500000.0  1467.0
#
#         transaction                furnishing   bathroom   balcony  \
# 0                 1     FurnishingUnfurnished  Bathroom4  Balcony4
# 1                 1     FurnishingUnfurnished  Bathroom4  Balcony4
# 2                 1     FurnishingUnfurnished  Bathroom4  Balcony4
# 3                 1     FurnishingUnfurnished  Bathroom1  Balcony1
# 4                 1  FurnishingSemi-Furnished  Bathroom2  Balcony2
# ...             ...                       ...        ...       ...
# 289523            1     FurnishingUnfurnished  Bathroom3       NaN
# 289524            1     FurnishingUnfurnished  Bathroom3       NaN
# 289525            1     FurnishingUnfurnished  Bathroom1       NaN
# 289526            1     FurnishingUnfurnished  Bathroom2       NaN
# 289527            1     FurnishingUnfurnished  Bathroom3       NaN
#
#        numberOfRooms   latitude  longitude
# 0                NaN        NaN        NaN
# 1                  4  28.404755  77.370169
# 2                  4  28.369477  77.371623
# 3                  1  28.404723  77.356094
# 4                  3  28.417834  77.367077
# ...              ...        ...        ...
# 289523             4  13.047710  80.149220
# 289524             3  12.821477  80.204775
# 289525             2  12.705000  79.974890
# 289526             2  12.884633  80.187252
# 289527             3  13.023781  80.199446
#
# [289528 rows x 10 columns]

# %%
df['furnishing']
# Out:
# 0            FurnishingUnfurnished
# 1            FurnishingUnfurnished
# 2            FurnishingUnfurnished
# 3            FurnishingUnfurnished
# 4         FurnishingSemi-Furnished
#                     ...
# 289523       FurnishingUnfurnished
# 289524       FurnishingUnfurnished
# 289525       FurnishingUnfurnished
# 289526       FurnishingUnfurnished
# 289527       FurnishingUnfurnished
# Name: furnishing, Length: 289528, dtype: object

# %%
new = df[:]

# %%
new
# Out:
#                                                     title       price    area  \
# 0       4 BHK Flat  for Sale in  Adore Presidential Wo...  12500000.0  2925.0
# 1       4 BHK Flat  for Sale in  Adore Presidential Wo...  12500000.0  2925.0
# 2       4 BHK Flat  for Sale in  BPTP Parkland Pride, ...  11800000.0  3150.0
# 3       1 BHK Flat  for Sale in  Amolik Sankalp, Secto...   2400000.0   337.0
# 4       3 BHK Flat  for Sale in  Puri Amanvilas, Secto...  11500000.0  1110.0
# ...                                                   ...         ...     ...
# 289523             4 BHK Flat for Sale in  Porur, Chennai  17900000.0  2001.0
# 289524           3 BHK Villa for Sale in Siruseri Chennai  14300000.0  1895.0
# 289525           2 BHK Flat for Sale in  Paranur, Chennai  11000000.0  1248.0
# 289526     2 BHK Flat for Sale in  Sithalapakkam, Chennai   4790000.0  1083.0
# 289527     3 BHK Flat for Sale in  Ekkatuthangal, Chennai  21500000.0  1467.0
#
#         transaction                furnishing   bathroom   balcony  \
# 0                 1     FurnishingUnfurnished  Bathroom4  Balcony4
# 1                 1     FurnishingUnfurnished  Bathroom4  Balcony4
# 2                 1     FurnishingUnfurnished  Bathroom4  Balcony4
# 3                 1     FurnishingUnfurnished  Bathroom1  Balcony1
# 4                 1  FurnishingSemi-Furnished  Bathroom2  Balcony2
# ...             ...                       ...        ...       ...
# 289523            1     FurnishingUnfurnished  Bathroom3       NaN
# 289524            1     FurnishingUnfurnished  Bathroom3       NaN
# 289525            1     FurnishingUnfurnished  Bathroom1       NaN
# 289526            1     FurnishingUnfurnished  Bathroom2       NaN
# 289527            1     FurnishingUnfurnished  Bathroom3       NaN
#
#        numberOfRooms   latitude  longitude
# 0                NaN        NaN        NaN
# 1                  4  28.404755  77.370169
# 2                  4  28.369477  77.371623
# 3                  1  28.404723  77.356094
# 4                  3  28.417834  77.367077
# ...              ...        ...        ...
# 289523             4  13.047710  80.149220
# 289524             3  12.821477  80.204775
# 289525             2  12.705000  79.974890
# 289526             2  12.884633  80.187252
# 289527             3  13.023781  80.199446
#
# [289528 rows x 10 columns]

# %%
df = new[:]

# %%
import pandas as pd

# Suppose your DataFrame 'df' is already loaded and contains many columns.
# First, let's inspect the unique values in the 'furnishing' column to ensure our mapping is correct.
print("Before mapping, unique furnishing values:", df["furnishing"].unique())

# Define a mapping dictionary that converts furnishing strings to integers.
furnishing_mapping = {
    "FurnishingUnfurnished": 0,
    "FurnishingSemi-Furnished": 1,
    # If you have other categories, add them here.
    # For example: "FurnishingFully-Furnished": 2,
}

# Apply the mapping only to the 'furnishing' column.
# This will replace the string values with the corresponding numeric codes.
df["furnishing"] = df["furnishing"].map(furnishing_mapping)

# Optionally, convert the column to a nullable integer type (if there are missing values)
df["furnishing"] = df["furnishing"].astype("Int64")

# Verify that only the 'furnishing' column has been modified:
print("After mapping, unique furnishing values:", df["furnishing"].unique())
print(df.head())
# Out:
# Before mapping, unique furnishing values: ['FurnishingUnfurnished' 'FurnishingSemi-Furnished' 'FurnishingFurnished'
#  nan]
# After mapping, unique furnishing values: <IntegerArray>
# [0, 1, <NA>]
# Length: 3, dtype: Int64
#                                                title       price    area  \
# 0  4 BHK Flat  for Sale in  Adore Presidential Wo...  12500000.0  2925.0
# 1  4 BHK Flat  for Sale in  Adore Presidential Wo...  12500000.0  2925.0
# 2  4 BHK Flat  for Sale in  BPTP Parkland Pride, ...  11800000.0  3150.0
# 3  1 BHK Flat  for Sale in  Amolik Sankalp, Secto...   2400000.0   337.0
# 4  3 BHK Flat  for Sale in  Puri Amanvilas, Secto...  11500000.0  1110.0
#
#    transaction  furnishing   bathroom   balcony numberOfRooms   latitude  \
# 0            1           0  Bathroom4  Balcony4           NaN        NaN
# 1            1           0  Bathroom4  Balcony4             4  28.404755
# 2            1           0  Bathroom4  Balcony4             4  28.369477
# 3            1           0  Bathroom1  Balcony1             1  28.404723
# 4            1           1  Bathroom2  Balcony2             3  28.417834
#
#    longitude
# 0        NaN
# 1  77.370169
# 2  77.371623
# 3  77.356094
# 4  77.367077

# %%
df
# Out:
#                                                     title       price    area  \
# 0       4 BHK Flat  for Sale in  Adore Presidential Wo...  12500000.0  2925.0
# 1       4 BHK Flat  for Sale in  Adore Presidential Wo...  12500000.0  2925.0
# 2       4 BHK Flat  for Sale in  BPTP Parkland Pride, ...  11800000.0  3150.0
# 3       1 BHK Flat  for Sale in  Amolik Sankalp, Secto...   2400000.0   337.0
# 4       3 BHK Flat  for Sale in  Puri Amanvilas, Secto...  11500000.0  1110.0
# ...                                                   ...         ...     ...
# 289523             4 BHK Flat for Sale in  Porur, Chennai  17900000.0  2001.0
# 289524           3 BHK Villa for Sale in Siruseri Chennai  14300000.0  1895.0
# 289525           2 BHK Flat for Sale in  Paranur, Chennai  11000000.0  1248.0
# 289526     2 BHK Flat for Sale in  Sithalapakkam, Chennai   4790000.0  1083.0
# 289527     3 BHK Flat for Sale in  Ekkatuthangal, Chennai  21500000.0  1467.0
#
#         transaction  furnishing   bathroom   balcony numberOfRooms   latitude  \
# 0                 1           0  Bathroom4  Balcony4           NaN        NaN
# 1                 1           0  Bathroom4  Balcony4             4  28.404755
# 2                 1           0  Bathroom4  Balcony4             4  28.369477
# 3                 1           0  Bathroom1  Balcony1             1  28.404723
# 4                 1           1  Bathroom2  Balcony2             3  28.417834
# ...             ...         ...        ...       ...           ...        ...
# 289523            1           0  Bathroom3       NaN             4  13.047710
# 289524            1           0  Bathroom3       NaN             3  12.821477
# 289525            1           0  Bathroom1       NaN             2  12.705000
# 289526            1           0  Bathroom2       NaN             2  12.884633
# 289527            1           0  Bathroom3       NaN             3  13.023781
#
#         longitude
# 0             NaN
# 1       77.370169
# 2       77.371623
# 3       77.356094
# 4       77.367077
# ...           ...
# 289523  80.149220
# 289524  80.204775
# 289525  79.974890
# 289526  80.187252
# 289527  80.199446
#
# [289528 rows x 10 columns]

# %%
df['bathroom']
# Out:
# 0         Bathroom4
# 1         Bathroom4
# 2         Bathroom4
# 3         Bathroom1
# 4         Bathroom2
#             ...
# 289523    Bathroom3
# 289524    Bathroom3
# 289525    Bathroom1
# 289526    Bathroom2
# 289527    Bathroom3
# Name: bathroom, Length: 289528, dtype: object

# %%
import pandas as pd

# Using str.extract to get only the numeric part and converting to Int64 (nullable integer)
df["bathroom"] = df["bathroom"].str.extract(r'(\d+)', expand=False).astype("Int64")

# Verify the conversion
print(df["bathroom"].head())
print(df["bathroom"].dtype)
# Out:
# 0    4
# 1    4
# 2    4
# 3    1
# 4    2
# Name: bathroom, dtype: Int64
# Int64

# %%
df
# Out:
#                                                     title       price    area  \
# 0       4 BHK Flat  for Sale in  Adore Presidential Wo...  12500000.0  2925.0
# 1       4 BHK Flat  for Sale in  Adore Presidential Wo...  12500000.0  2925.0
# 2       4 BHK Flat  for Sale in  BPTP Parkland Pride, ...  11800000.0  3150.0
# 3       1 BHK Flat  for Sale in  Amolik Sankalp, Secto...   2400000.0   337.0
# 4       3 BHK Flat  for Sale in  Puri Amanvilas, Secto...  11500000.0  1110.0
# ...                                                   ...         ...     ...
# 289523             4 BHK Flat for Sale in  Porur, Chennai  17900000.0  2001.0
# 289524           3 BHK Villa for Sale in Siruseri Chennai  14300000.0  1895.0
# 289525           2 BHK Flat for Sale in  Paranur, Chennai  11000000.0  1248.0
# 289526     2 BHK Flat for Sale in  Sithalapakkam, Chennai   4790000.0  1083.0
# 289527     3 BHK Flat for Sale in  Ekkatuthangal, Chennai  21500000.0  1467.0
#
#         transaction  furnishing  bathroom   balcony numberOfRooms   latitude  \
# 0                 1           0         4  Balcony4           NaN        NaN
# 1                 1           0         4  Balcony4             4  28.404755
# 2                 1           0         4  Balcony4             4  28.369477
# 3                 1           0         1  Balcony1             1  28.404723
# 4                 1           1         2  Balcony2             3  28.417834
# ...             ...         ...       ...       ...           ...        ...
# 289523            1           0         3       NaN             4  13.047710
# 289524            1           0         3       NaN             3  12.821477
# 289525            1           0         1       NaN             2  12.705000
# 289526            1           0         2       NaN             2  12.884633
# 289527            1           0         3       NaN             3  13.023781
#
#         longitude
# 0             NaN
# 1       77.370169
# 2       77.371623
# 3       77.356094
# 4       77.367077
# ...           ...
# 289523  80.149220
# 289524  80.204775
# 289525  79.974890
# 289526  80.187252
# 289527  80.199446
#
# [289528 rows x 10 columns]

# %%
df['balcony']
# Out:
# 0         Balcony4
# 1         Balcony4
# 2         Balcony4
# 3         Balcony1
# 4         Balcony2
#             ...
# 289523         NaN
# 289524         NaN
# 289525         NaN
# 289526         NaN
# 289527         NaN
# Name: balcony, Length: 289528, dtype: object

# %%
df["balcony"] = df["balcony"].str.extract(r'(\d+)', expand=False).astype("Int64")

# %%
df
# Out:
#                                                     title       price    area  \
# 0       4 BHK Flat  for Sale in  Adore Presidential Wo...  12500000.0  2925.0
# 1       4 BHK Flat  for Sale in  Adore Presidential Wo...  12500000.0  2925.0
# 2       4 BHK Flat  for Sale in  BPTP Parkland Pride, ...  11800000.0  3150.0
# 3       1 BHK Flat  for Sale in  Amolik Sankalp, Secto...   2400000.0   337.0
# 4       3 BHK Flat  for Sale in  Puri Amanvilas, Secto...  11500000.0  1110.0
# ...                                                   ...         ...     ...
# 289523             4 BHK Flat for Sale in  Porur, Chennai  17900000.0  2001.0
# 289524           3 BHK Villa for Sale in Siruseri Chennai  14300000.0  1895.0
# 289525           2 BHK Flat for Sale in  Paranur, Chennai  11000000.0  1248.0
# 289526     2 BHK Flat for Sale in  Sithalapakkam, Chennai   4790000.0  1083.0
# 289527     3 BHK Flat for Sale in  Ekkatuthangal, Chennai  21500000.0  1467.0
#
#         transaction  furnishing  bathroom  balcony numberOfRooms   latitude  \
# 0                 1           0         4        4           NaN        NaN
# 1                 1           0         4        4             4  28.404755
# 2                 1           0         4        4             4  28.369477
# 3                 1           0         1        1             1  28.404723
# 4                 1           1         2        2             3  28.417834
# ...             ...         ...       ...      ...           ...        ...
# 289523            1           0         3     <NA>             4  13.047710
# 289524            1           0         3     <NA>             3  12.821477
# 289525            1           0         1     <NA>             2  12.705000
# 289526            1           0         2     <NA>             2  12.884633
# 289527            1           0         3     <NA>             3  13.023781
#
#         longitude
# 0             NaN
# 1       77.370169
# 2       77.371623
# 3       77.356094
# 4       77.367077
# ...           ...
# 289523  80.149220
# 289524  80.204775
# 289525  79.974890
# 289526  80.187252
# 289527  80.199446
#
# [289528 rows x 10 columns]

# %%
null_count = df["bathroom"].isna().sum()
print("Number of null values in the 'bathroom' column:", null_count)
# Out:
# Number of null values in the 'bathroom' column: 3288

# %%
print("Null values per column:")
print(df.isna().sum())
# Out:
# Null values per column:
# title                0
# price             4378
# area              1656
# transaction        391
# furnishing       22624
# bathroom          3288
# balcony          89130
# numberOfRooms    11461
# latitude         16648
# longitude        16648
# dtype: int64

# %%
#removing the area null values 
#also removing the lat and long null value rows 
df.dropna(subset=['area', 'latitude', 'longitude'], inplace=True)

# %%
df.isna().sum()
# Out:
# title                0
# price             2644
# area                 0
# transaction        163
# furnishing       19061
# bathroom          1632
# balcony          84442
# numberOfRooms     1007
# latitude             0
# longitude            0
# dtype: int64

# %%
import pandas as pd

# Convert 'bathroom' and 'numberOfRooms' to numeric
df['bathroom'] = pd.to_numeric(df['bathroom'], errors='coerce')
df['numberOfRooms'] = pd.to_numeric(df['numberOfRooms'], errors='coerce')

# Create bins for price and area. Adjust the number of bins as needed.
df['price_bin'] = pd.cut(df['price'], bins=10)
df['area_bin']  = pd.cut(df['area'], bins=10)

# Calculate overall medians for fallback
overall_median_bathroom = df['bathroom'].median()
overall_median_rooms = df['numberOfRooms'].median()

# Impute missing 'bathroom' values using the median within each (price_bin, area_bin) group.
df['bathroom'] = df.groupby(['price_bin', 'area_bin'])['bathroom'] \
                   .transform(lambda x: x.fillna(x.median() if pd.notnull(x.median()) else overall_median_bathroom))

# Impute missing 'numberOfRooms' values similarly
df['numberOfRooms'] = df.groupby(['price_bin', 'area_bin'])['numberOfRooms'] \
                        .transform(lambda x: x.fillna(x.median() if pd.notnull(x.median()) else overall_median_rooms))

# (Optional) Convert the imputed columns to a nullable integer type if desired
df['bathroom'] = df['bathroom'].astype('Int64')
df['numberOfRooms'] = df['numberOfRooms'].astype('Int64')

# Drop the helper binning columns if no longer needed
df.drop(columns=['price_bin', 'area_bin'], inplace=True)

# Verify the results:
print("Missing values per column after imputation:")
print(df[['bathroom', 'numberOfRooms']].isna().sum())
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_15776\2814916656.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['bathroom'] = df.groupby(['price_bin', 'area_bin'])['bathroom'] \
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_15776\2814916656.py:20: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['numberOfRooms'] = df.groupby(['price_bin', 'area_bin'])['numberOfRooms'] \
# Missing values per column after imputation:
# bathroom         2644
# numberOfRooms    2644
# dtype: int64

# %%
df.isna().sum()
# Out:
# title                0
# price             2644
# area                 0
# transaction        163
# furnishing       19061
# bathroom          2644
# balcony          84442
# numberOfRooms     2644
# latitude             0
# longitude            0
# dtype: int64

# %%
import pandas as pd

# Convert the relevant columns to numeric
df['bathroom'] = pd.to_numeric(df['bathroom'], errors='coerce')
df['numberOfRooms'] = pd.to_numeric(df['numberOfRooms'], errors='coerce')
df['balcony'] = pd.to_numeric(df['balcony'], errors='coerce')

# Create bins for price and area. Adjust number of bins based on your data.
df['price_bin'] = pd.cut(df['price'], bins=10)
df['area_bin']  = pd.cut(df['area'], bins=10)

# Calculate overall medians as fallback values
overall_median_bathroom = df['bathroom'].median()
overall_median_rooms    = df['numberOfRooms'].median()
overall_median_balcony  = df['balcony'].median()

# Impute missing 'bathroom' values within each (price_bin, area_bin) group.
df['bathroom'] = df.groupby(['price_bin', 'area_bin'])['bathroom'] \
                   .transform(lambda x: x.fillna(x.median() if pd.notnull(x.median()) else overall_median_bathroom))

# Impute missing 'numberOfRooms' values within each (price_bin, area_bin) group.
df['numberOfRooms'] = df.groupby(['price_bin', 'area_bin'])['numberOfRooms'] \
                        .transform(lambda x: x.fillna(x.median() if pd.notnull(x.median()) else overall_median_rooms))

# Impute missing 'balcony' values within each (price_bin, area_bin) group.
df['balcony'] = df.groupby(['price_bin', 'area_bin'])['balcony'] \
                  .transform(lambda x: x.fillna(x.median() if pd.notnull(x.median()) else overall_median_balcony))

# Optionally convert the columns to a nullable integer type (if you want integer values)
df['bathroom'] = df['bathroom'].astype("Int64")
df['numberOfRooms'] = df['numberOfRooms'].astype("Int64")
df['balcony'] = df['balcony'].astype("Int64")

# Drop the helper binning columns
df.drop(columns=['price_bin', 'area_bin'], inplace=True)

# Verify the results:
print("Missing values after imputation:")
print(df[['bathroom', 'numberOfRooms', 'balcony']].isna().sum())
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_15776\2557627582.py:18: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['bathroom'] = df.groupby(['price_bin', 'area_bin'])['bathroom'] \
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_15776\2557627582.py:22: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['numberOfRooms'] = df.groupby(['price_bin', 'area_bin'])['numberOfRooms'] \
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_15776\2557627582.py:26: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['balcony'] = df.groupby(['price_bin', 'area_bin'])['balcony'] \
# c:\Users\ASUS\anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:2328, in ExtensionBlock.fillna(self, value, limit, inplace, downcast, using_cow, already_warned)
#    2327 try:
# -> 2328     new_values = self.values.fillna(
#    2329         value=value, method=None, limit=limit, copy=copy
#    2330     )
#    2331 except TypeError:
#    2332     # 3rd party EA that has not implemented copy keyword yet
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:266, in BaseMaskedArray.fillna(self, value, method, limit, copy)
#     265             new_values = self[:]
# --> 266         new_values[mask] = value
#     267 else:
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:314, in BaseMaskedArray.__setitem__(self, key, value)
#     313 else:
# --> 314     value = self._validate_setitem_value(value)
#     315     self._data[key] = value
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:305, in BaseMaskedArray._validate_setitem_value(self, value)
#     301     # TODO: unsigned checks
#     302
#     303 # Note: without the "str" here, the f-string rendering raises in
#     304 #  py38 builds.
# --> 305 raise TypeError(f"Invalid value '{str(value)}' for dtype {self.dtype}")
#
# TypeError: Invalid value '7.5' for dtype Int64
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 27
#      22 df['numberOfRooms'] = df.groupby(['price_bin', 'area_bin'])['numberOfRooms'] \
#      23                         .transform(lambda x: x.fillna(x.median() if pd.notnull(x.median()) else overall_median_rooms))
#      25 # Impute missing 'balcony' values within each (price_bin, area_bin) group.
#      26 df['balcony'] = df.groupby(['price_bin', 'area_bin'])['balcony'] \
# ---> 27                   .transform(lambda x: x.fillna(x.median() if pd.notnull(x.median()) else overall_median_balcony))
#      29 # Optionally convert the columns to a nullable integer type (if you want integer values)
#      30 df['bathroom'] = df['bathroom'].astype("Int64")
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:517, in SeriesGroupBy.transform(self, func, engine, engine_kwargs, *args, **kwargs)
#     514 @Substitution(klass="Series", example=__examples_series_doc)
#     515 @Appender(_transform_template)
#     516 def transform(self, func, *args, engine=None, engine_kwargs=None, **kwargs):
# --> 517     return self._transform(
#     518         func, *args, engine=engine, engine_kwargs=engine_kwargs, **kwargs
#     519     )
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:2021, in GroupBy._transform(self, func, engine, engine_kwargs, *args, **kwargs)
#    2018     warn_alias_replacement(self, orig_func, func)
#    2020 if not isinstance(func, str):
# -> 2021     return self._transform_general(func, engine, engine_kwargs, *args, **kwargs)
#    2023 elif func not in base.transform_kernel_allowlist:
#    2024     msg = f"'{func}' is not a valid function name for transform(name)"
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:557, in SeriesGroupBy._transform_general(self, func, engine, engine_kwargs, *args, **kwargs)
#     552 for name, group in self._grouper.get_iterator(
#     553     self._obj_with_exclusions, axis=self.axis
#     554 ):
#     555     # this setattr is needed for test_transform_lambda_with_datetimetz
#     556     object.__setattr__(group, "name", name)
# --> 557     res = func(group, *args, **kwargs)
#     559     results.append(klass(res, index=group.index))
#     561 # check for empty "results" to avoid concat ValueError
#
# Cell In[47], line 27, in <lambda>(x)
#      22 df['numberOfRooms'] = df.groupby(['price_bin', 'area_bin'])['numberOfRooms'] \
#      23                         .transform(lambda x: x.fillna(x.median() if pd.notnull(x.median()) else overall_median_rooms))
#      25 # Impute missing 'balcony' values within each (price_bin, area_bin) group.
#      26 df['balcony'] = df.groupby(['price_bin', 'area_bin'])['balcony'] \
# ---> 27                   .transform(lambda x: x.fillna(x.median() if pd.notnull(x.median()) else overall_median_balcony))
#      29 # Optionally convert the columns to a nullable integer type (if you want integer values)
#      30 df['bathroom'] = df['bathroom'].astype("Int64")
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\generic.py:7349, in NDFrame.fillna(self, value, method, axis, inplace, limit, downcast)
#    7342     else:
#    7343         raise TypeError(
#    7344             '"value" parameter must be a scalar, dict '
#    7345             "or Series, but you passed a "
#    7346             f'"{type(value).__name__}"'
#    7347         )
# -> 7349     new_data = self._mgr.fillna(
#    7350         value=value, limit=limit, inplace=inplace, downcast=downcast
#    7351     )
#    7353 elif isinstance(value, (dict, ABCSeries)):
#    7354     if axis == 1:
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\internals\base.py:186, in DataManager.fillna(self, value, limit, inplace, downcast)
#     182 if limit is not None:
#     183     # Do this validation even if we go through one of the no-op paths
#     184     limit = libalgos.validate_limit(None, limit=limit)
# --> 186 return self.apply_with_block(
#     187     "fillna",
#     188     value=value,
#     189     limit=limit,
#     190     inplace=inplace,
#     191     downcast=downcast,
#     192     using_cow=using_copy_on_write(),
#     193     already_warned=_AlreadyWarned(),
#     194 )
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:2334, in ExtensionBlock.fillna(self, value, limit, inplace, downcast, using_cow, already_warned)
#    2331 except TypeError:
#    2332     # 3rd party EA that has not implemented copy keyword yet
#    2333     refs = None
# -> 2334     new_values = self.values.fillna(value=value, method=None, limit=limit)
#    2335     # issue the warning *after* retrying, in case the TypeError
#    2336     #  was caused by an invalid fill_value
#    2337     warnings.warn(
#    2338         # GH#53278
#    2339         "ExtensionArray.fillna added a 'copy' keyword in pandas "
#    (...)
#    2345         stacklevel=find_stack_level(),
#    2346     )
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:266, in BaseMaskedArray.fillna(self, value, method, limit, copy)
#     264         else:
#     265             new_values = self[:]
# --> 266         new_values[mask] = value
#     267 else:
#     268     if copy:
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:314, in BaseMaskedArray.__setitem__(self, key, value)
#     312     self._mask[key] = True
#     313 else:
# --> 314     value = self._validate_setitem_value(value)
#     315     self._data[key] = value
#     316     self._mask[key] = False
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:305, in BaseMaskedArray._validate_setitem_value(self, value)
#     300         return value
#     301     # TODO: unsigned checks
#     302
#     303 # Note: without the "str" here, the f-string rendering raises in
#     304 #  py38 builds.
# --> 305 raise TypeError(f"Invalid value '{str(value)}' for dtype {self.dtype}")
#
# TypeError: Invalid value '7.5' for dtype Int64

# %%
df
# Out:
#                                                   title       price    area  \
# 0            3 BHK Flat  for Sale in  Yapral, Hyderabad   7650000.0  1500.0
# 1          3 BHK Flat  for Sale in  Kompally, Hyderabad  11300000.0  1485.0
# 2            4 BHK Flat  for Sale in  Yapral, Hyderabad  18200000.0  2808.0
# 3        2 BHK Flat  for Sale in  Shamshabad, Hyderabad  12700000.0  1590.0
# 4     4 BHK Flat  for Sale in  Uppal, NH 2 2, Hyderabad  26300000.0  3330.0
# ...                                                 ...         ...     ...
# 2995         3 BHK Flat  for Sale in  Yapral, Hyderabad  15400000.0  1450.0
# 2996  5 BHK  House for Sale in Sachivalaya Colony, V...  35000000.0  4800.0
# 2997  3 BHK Flat  for Sale in  Tellapur, Outer Ring ...  14500000.0  2000.0
# 2998  5 BHK  House for Sale in Kukatpally, NH 9 Hyde...  23000000.0  2600.0
# 2999          4 BHK Villa for Sale in Nagaram Hyderabad  16700000.0  2700.0
#
#       transaction  furnishing  bathroom  balcony  numberOfRooms   latitude  \
# 0               1           0         3        2              3  17.511748
# 1               1           0         3        2              3  17.538052
# 2               1           0         3        2              4  17.515017
# 3               1           0         2        2              2  17.293140
# 4               1           0         4        2              4  17.403512
# ...           ...         ...       ...      ...            ...        ...
# 2995            0           1         3        1              3  17.512838
# 2996            0           0         7        2              5  17.328104
# 2997            0           1         3        2              3  17.460620
# 2998            0           0         6        3              5  17.493160
# 2999            0           0         4        1              4  17.481821
#
#       longitude
# 0     78.534582
# 1     78.483948
# 2     78.540123
# 3     78.414610
# 4     78.549846
# ...         ...
# 2995  78.545034
# 2996  78.571999
# 2997  78.275162
# 2998  78.402277
# 2999  78.604225
#
# [2824 rows x 10 columns]

# %%
df.isna().sum()
# Out:
# title              0
# price              0
# area               0
# transaction        4
# furnishing       476
# bathroom           0
# balcony            0
# numberOfRooms      0
# latitude           0
# longitude          0
# dtype: int64

# %%
# Fill null values in 'transaction' column with its mode value.
transaction_mode = df['transaction'].mode()[0]
df['transaction'] = df['transaction'].fillna(transaction_mode)

# Fill null values in 'furnishing' column with its mode value.
furnishing_mode = df['furnishing'].mode()[0]
df['furnishing'] = df['furnishing'].fillna(furnishing_mode)

# Verify that the null values have been filled:
print("Missing values after filling mode:")
print(df[['transaction', 'furnishing']].isna().sum())
# Out:
# Missing values after filling mode:
# transaction    0
# furnishing     0
# dtype: int64

# %%
df.isna().sum()
# Out:
# title            0
# price            0
# area             0
# transaction      0
# furnishing       0
# bathroom         0
# balcony          0
# numberOfRooms    0
# latitude         0
# longitude        0
# dtype: int64

# %%
df
# Out:
#                                                     title       price    area  \
# 1       4 BHK Flat  for Sale in  Adore Presidential Wo...  12500000.0  2925.0
# 2       4 BHK Flat  for Sale in  BPTP Parkland Pride, ...  11800000.0  3150.0
# 3       1 BHK Flat  for Sale in  Amolik Sankalp, Secto...   2400000.0   337.0
# 4       3 BHK Flat  for Sale in  Puri Amanvilas, Secto...  11500000.0  1110.0
# 5       3 BHK Flat  for Sale in  Bptp District 5, Sect...   9600000.0  1350.0
# ...                                                   ...         ...     ...
# 289523             4 BHK Flat for Sale in  Porur, Chennai  17900000.0  2001.0
# 289524           3 BHK Villa for Sale in Siruseri Chennai  14300000.0  1895.0
# 289525           2 BHK Flat for Sale in  Paranur, Chennai  11000000.0  1248.0
# 289526     2 BHK Flat for Sale in  Sithalapakkam, Chennai   4790000.0  1083.0
# 289527     3 BHK Flat for Sale in  Ekkatuthangal, Chennai  21500000.0  1467.0
#
#         transaction  furnishing  bathroom  balcony  numberOfRooms   latitude  \
# 1                 1           0         4        4              4  28.404755
# 2                 1           0         4        4              4  28.369477
# 3                 1           0         1        1              1  28.404723
# 4                 1           1         2        2              3  28.417834
# 5                 1           0         2        3              3  28.404755
# ...             ...         ...       ...      ...            ...        ...
# 289523            1           0         3     <NA>              4  13.047710
# 289524            1           0         3     <NA>              3  12.821477
# 289525            1           0         1     <NA>              2  12.705000
# 289526            1           0         2     <NA>              2  12.884633
# 289527            1           0         3     <NA>              3  13.023781
#
#         longitude                   price_bin             area_bin
# 1       77.370169  (-9899900.0, 1000090000.0]  (-494.969, 49597.9]
# 2       77.371623  (-9899900.0, 1000090000.0]  (-494.969, 49597.9]
# 3       77.356094  (-9899900.0, 1000090000.0]  (-494.969, 49597.9]
# 4       77.367077  (-9899900.0, 1000090000.0]  (-494.969, 49597.9]
# 5       77.370169  (-9899900.0, 1000090000.0]  (-494.969, 49597.9]
# ...           ...                         ...                  ...
# 289523  80.149220  (-9899900.0, 1000090000.0]  (-494.969, 49597.9]
# 289524  80.204775  (-9899900.0, 1000090000.0]  (-494.969, 49597.9]
# 289525  79.974890  (-9899900.0, 1000090000.0]  (-494.969, 49597.9]
# 289526  80.187252  (-9899900.0, 1000090000.0]  (-494.969, 49597.9]
# 289527  80.199446  (-9899900.0, 1000090000.0]  (-494.969, 49597.9]
#
# [271466 rows x 12 columns]

# %%
# Save the DataFrame to a CSV file without the index column
df.to_csv("final_data.csv", index=False)
print("Data saved to final_data.csv")
# Out:
# Data saved to final_data.csv

# %%
# Create a new DataFrame with only the latitude and longitude columns
lat_long_df = df[['latitude', 'longitude']].copy()

# Save the new DataFrame to a separate CSV file
lat_long_df.to_csv("lat_long.csv", index=False)

print("Latitude and longitude data saved to 'lat_long.csv'")
# Out:
# Latitude and longitude data saved to 'lat_long.csv'
