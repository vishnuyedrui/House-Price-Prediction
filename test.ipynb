# %%
import numpy as np
import requests
import json
import time
import pandas as pd
from math import radians, cos, sin, asin, sqrt
from rtree import index

# --------------------------
# Helper Functions
# --------------------------
def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance (in km) between two points on Earth.
    """
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a))
    r = 6371  # Radius of Earth in kilometers
    return c * r

# Overpass query templates for different amenity types
amenity_queries = {
    'hospital': """
        [out:json];
        (
          node["amenity"="hospital"]({min_lat},{min_lon},{max_lat},{max_lon});
          way["amenity"="hospital"]({min_lat},{min_lon},{max_lat},{max_lon});
          node["amenity"="clinic"]({min_lat},{min_lon},{max_lat},{max_lon});
        );
        out center;
    """,
    'public_transport': """
        [out:json];
        (
          node["public_transport"="station"]({min_lat},{min_lon},{max_lat},{max_lon});
          node["highway"="bus_stop"]({min_lat},{min_lon},{max_lat},{max_lon});
          node["railway"="station"]({min_lat},{min_lon},{max_lat},{max_lon});
        );
        out center;
    """,
    'education': """
        [out:json];
        (
          node["amenity"~"^(school|college|university)$"]({min_lat},{min_lon},{max_lat},{max_lon});
          way["amenity"~"^(school|college|university)$"]({min_lat},{min_lon},{max_lat},{max_lon});
        );
        out center;
    """,
    'govt_office': """
        [out:json];
        (
          node["office"="government"]({min_lat},{min_lon},{max_lat},{max_lon});
          way["office"="government"]({min_lat},{min_lon},{max_lat},{max_lon});
        );
        out center;
    """,
    'highway': """
        [out:json];
        (
          way["highway"~"^(motorway|trunk|primary|secondary|tertiary)$"]({min_lat},{min_lon},{max_lat},{max_lon});
        );
        out center;
    """,
    'mall': """
        [out:json];
        (
          node["shop"="mall"]({min_lat},{min_lon},{max_lat},{max_lon});
          way["shop"="mall"]({min_lat},{min_lon},{max_lat},{max_lon});
        );
        out center;
    """,
    'park': """
        [out:json];
        (
          node["leisure"="park"]({min_lat},{min_lon},{max_lat},{max_lon});
          way["leisure"="park"]({min_lat},{min_lon},{max_lat},{max_lon});
        );
        out center;
    """,
    'airport': """
        [out:json];
        (
          node["aeroway"="aerodrome"]({min_lat},{min_lon},{max_lat},{max_lon});
          way["aeroway"="aerodrome"]({min_lat},{min_lon},{max_lat},{max_lon});
        );
        out center;
    """
}

overpass_url = "https://overpass-api.de/api/interpreter"

def download_amenity_points(bbox, query_template, retries=3):
    """
    Download amenity data for a given bounding box using the provided query template.
    Retries if a request fails.
    """
    min_lat, min_lon, max_lat, max_lon = bbox
    query = query_template.format(min_lat=min_lat, min_lon=min_lon, max_lat=max_lat, max_lon=max_lon)
    for attempt in range(retries):
        try:
            response = requests.get(overpass_url, params={'data': query}, timeout=60)
            # If response is empty, raise an error to trigger a retry
            if response.text.strip() == "":
                raise ValueError("Empty response")
            data = response.json()
            points = []
            for element in data.get('elements', []):
                if element['type'] == 'node':
                    points.append((element['lat'], element['lon']))
                elif 'center' in element:
                    center = element['center']
                    points.append((center['lat'], center['lon']))
            return points
        except Exception as e:
            print(f"Error downloading amenity data for bbox {bbox} on attempt {attempt+1}: {e}")
            time.sleep(2)
    return []

def get_amenity_data_for_bbox(bbox):
    """
    For a given bbox, download amenity data for all types.
    """
    amenity_data = {}
    for amenity_type, query_template in amenity_queries.items():
        print(f"Downloading {amenity_type} data for bbox {bbox}...")
        points = download_amenity_points(bbox, query_template)
        amenity_data[amenity_type] = list(set(points))  # deduplicate points
        print(f"Found {len(amenity_data[amenity_type])} unique {amenity_type} points.")
        time.sleep(1)  # be polite to the API
    return amenity_data

def build_spatial_index(points):
    """
    Build an R-tree spatial index for the given list of (lat, lon) points.
    """
    idx = index.Index()
    for i, (lat, lon) in enumerate(points):
        idx.insert(i, (lon, lat, lon, lat))
    return idx

def get_nearest_distance(lat, lon, idx, points):
    """
    Get the nearest distance (in km) between (lat, lon) and a set of points using the provided index.
    Returns -1 if no points are available.
    """
    if not points:
        return -1
    nearest = list(idx.nearest((lon, lat, lon, lat), 1))
    if nearest:
        nearest_idx = nearest[0]
        amenity_lat, amenity_lon = points[nearest_idx]
        return round(haversine(lon, lat, amenity_lon, amenity_lat), 3)
    return -1

def process_chunk(chunk_df):
    """
    Process a chunk (subset) of the CSV data:
      1. Compute the chunk's bounding box (with a small buffer).
      2. Download amenity data for that bbox.
      3. Build spatial indexes for each amenity type.
      4. Compute the nearest amenity distance for each row in the chunk.
    """
    # Compute bounding box for the chunk and add a buffer
    min_lat = chunk_df['latitude'].min()
    max_lat = chunk_df['latitude'].max()
    min_lon = chunk_df['longitude'].min()
    max_lon = chunk_df['longitude'].max()
    buffer = 0.1  # adjust as needed
    bbox = (min_lat - buffer, min_lon - buffer, max_lat + buffer, max_lon + buffer)
    
    # Download amenity data for this bbox
    amenity_data = get_amenity_data_for_bbox(bbox)
    
    # Build spatial indexes for each amenity type
    spatial_indexes = {}
    for amenity_type, points in amenity_data.items():
        spatial_indexes[amenity_type] = (build_spatial_index(points), points)
    
    # For each coordinate in the chunk, find the nearest distance for each amenity type
    results = []
    for i, row in chunk_df.iterrows():
        lat = row['latitude']
        lon = row['longitude']
        result = {
            "latitude": lat,
            "longitude": lon,
            "nearest_hospital": get_nearest_distance(lat, lon, *spatial_indexes.get('hospital', (None, []))),
            "nearest_public_transport": get_nearest_distance(lat, lon, *spatial_indexes.get('public_transport', (None, []))),
            "nearest_education": get_nearest_distance(lat, lon, *spatial_indexes.get('education', (None, []))),
            "nearest_govt_office": get_nearest_distance(lat, lon, *spatial_indexes.get('govt_office', (None, []))),
            "nearest_highway": get_nearest_distance(lat, lon, *spatial_indexes.get('highway', (None, []))),
            "nearest_mall": get_nearest_distance(lat, lon, *spatial_indexes.get('mall', (None, []))),
            "nearest_park": get_nearest_distance(lat, lon, *spatial_indexes.get('park', (None, []))),
            "nearest_airport": get_nearest_distance(lat, lon, *spatial_indexes.get('airport', (None, [])))
        }
        results.append(result)
    return results

# --------------------------
# Main Workflow: Process CSV in chunks
# --------------------------
def main():
    coordinates_df = pd.read_csv("lat and long.csv")
    all_results = []
    chunk_size = 3000
    num_chunks = (len(coordinates_df) + chunk_size - 1) // chunk_size
    print(f"Total rows: {len(coordinates_df)}, processing in {num_chunks} chunks of {chunk_size} rows each.")
    
    for i in range(num_chunks):
        print(f"\nProcessing chunk {i+1}/{num_chunks}...")
        chunk_df = coordinates_df.iloc[i*chunk_size:(i+1)*chunk_size]
        chunk_results = process_chunk(chunk_df)
        all_results.extend(chunk_results)
        # Save intermediate results for each chunk
        with open(f"results_chunk_{i+1}.json", "w") as outfile:
            json.dump(chunk_results, outfile, indent=4)
    
    # Save the final combined results
    with open("locations_amenities_list_total.json", "w") as outfile:
        json.dump(all_results, outfile, indent=4)
    print("All chunks processed and combined results saved.")

if __name__ == "__main__":
    main()
# Out:
# Total rows: 271466, processing in 91 chunks of 3000 rows each.
#
# Processing chunk 1/91...
# Downloading hospital data for bbox (28.05451431274414, 76.93120422363282, 28.7666660308838, 77.54757989999999)...
# Found 1800 unique hospital points.
# Downloading public_transport data for bbox (28.05451431274414, 76.93120422363282, 28.7666660308838, 77.54757989999999)...
# Found 2390 unique public_transport points.
# Downloading education data for bbox (28.05451431274414, 76.93120422363282, 28.7666660308838, 77.54757989999999)...
# Found 1605 unique education points.
# Downloading govt_office data for bbox (28.05451431274414, 76.93120422363282, 28.7666660308838, 77.54757989999999)...
# Found 238 unique govt_office points.
# Downloading highway data for bbox (28.05451431274414, 76.93120422363282, 28.7666660308838, 77.54757989999999)...
# Found 18166 unique highway points.
# Downloading mall data for bbox (28.05451431274414, 76.93120422363282, 28.7666660308838, 77.54757989999999)...
# Found 116 unique mall points.
# Downloading park data for bbox (28.05451431274414, 76.93120422363282, 28.7666660308838, 77.54757989999999)...
# Found 5779 unique park points.
# Downloading airport data for bbox (28.05451431274414, 76.93120422363282, 28.7666660308838, 77.54757989999999)...
# Found 5 unique airport points.
#
# Processing chunk 2/91...
# Downloading hospital data for bbox (18.789285699999997, 77.12002170000001, 28.59101357606, 86.33126)...
# Found 14686 unique hospital points.
# Downloading public_transport data for bbox (18.789285699999997, 77.12002170000001, 28.59101357606, 86.33126)...
# Found 5650 unique public_transport points.
# Downloading education data for bbox (18.789285699999997, 77.12002170000001, 28.59101357606, 86.33126)...
# Found 23336 unique education points.
# Downloading govt_office data for bbox (18.789285699999997, 77.12002170000001, 28.59101357606, 86.33126)...
# Found 2625 unique govt_office points.
# Downloading highway data for bbox (18.789285699999997, 77.12002170000001, 28.59101357606, 86.33126)...
# Found 193974 unique highway points.
# Downloading mall data for bbox (18.789285699999997, 77.12002170000001, 28.59101357606, 86.33126)...
# Found 379 unique mall points.
# Downloading park data for bbox (18.789285699999997, 77.12002170000001, 28.59101357606, 86.33126)...
# Found 7118 unique park points.
# Downloading airport data for bbox (18.789285699999997, 77.12002170000001, 28.59101357606, 86.33126)...
# Found 136 unique airport points.
#
# Processing chunk 3/91...
# Downloading hospital data for bbox (16.222984999999998, 76.8217353, 27.721111, 88.5318509)...
# Found 22297 unique hospital points.
# Downloading public_transport data for bbox (16.222984999999998, 76.8217353, 27.721111, 88.5318509)...
# Found 8922 unique public_transport points.
# Downloading education data for bbox (16.222984999999998, 76.8217353, 27.721111, 88.5318509)...
# Found 20767 unique education points.
# Downloading govt_office data for bbox (16.222984999999998, 76.8217353, 27.721111, 88.5318509)...
# Found 3042 unique govt_office points.
# Downloading highway data for bbox (16.222984999999998, 76.8217353, 27.721111, 88.5318509)...
# Found 274824 unique highway points.
# Downloading mall data for bbox (16.222984999999998, 76.8217353, 27.721111, 88.5318509)...
# Found 696 unique mall points.
# Downloading park data for bbox (16.222984999999998, 76.8217353, 27.721111, 88.5318509)...
# Found 8762 unique park points.
# Downloading airport data for bbox (16.222984999999998, 76.8217353, 27.721111, 88.5318509)...
# Found 176 unique airport points.
#
# Processing chunk 4/91...
# Downloading hospital data for bbox (22.6723951, 23.1599333, 28.788254170000002, 86.3710885)...
# Found 23841 unique hospital points.
# Downloading public_transport data for bbox (22.6723951, 23.1599333, 28.788254170000002, 86.3710885)...
# Error downloading amenity data for bbox (22.6723951, 23.1599333, 28.788254170000002, 86.3710885) on attempt 1: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (22.6723951, 23.1599333, 28.788254170000002, 86.3710885) on attempt 2: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Found 12688 unique public_transport points.
# Downloading education data for bbox (22.6723951, 23.1599333, 28.788254170000002, 86.3710885)...
# Found 32626 unique education points.
# Downloading govt_office data for bbox (22.6723951, 23.1599333, 28.788254170000002, 86.3710885)...
# Found 5433 unique govt_office points.
# Downloading highway data for bbox (22.6723951, 23.1599333, 28.788254170000002, 86.3710885)...
# Found 381230 unique highway points.
# Downloading mall data for bbox (22.6723951, 23.1599333, 28.788254170000002, 86.3710885)...
# Found 1729 unique mall points.
# Downloading park data for bbox (22.6723951, 23.1599333, 28.788254170000002, 86.3710885)...
# Found 20037 unique park points.
# Downloading airport data for bbox (22.6723951, 23.1599333, 28.788254170000002, 86.3710885)...
# Found 390 unique airport points.
#
# Processing chunk 5/91...
# Downloading hospital data for bbox (19.3833, 19.750730895996092, 75.43147430419921, 82.36444244384765)...
# Error downloading amenity data for bbox (19.3833, 19.750730895996092, 75.43147430419921, 82.36444244384765) on attempt 1: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Found 89052 unique hospital points.
# Downloading public_transport data for bbox (19.3833, 19.750730895996092, 75.43147430419921, 82.36444244384765)...
# Error downloading amenity data for bbox (19.3833, 19.750730895996092, 75.43147430419921, 82.36444244384765) on attempt 1: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (19.3833, 19.750730895996092, 75.43147430419921, 82.36444244384765) on attempt 2: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (19.3833, 19.750730895996092, 75.43147430419921, 82.36444244384765) on attempt 3: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Found 0 unique public_transport points.
# Downloading education data for bbox (19.3833, 19.750730895996092, 75.43147430419921, 82.36444244384765)...
# Error downloading amenity data for bbox (19.3833, 19.750730895996092, 75.43147430419921, 82.36444244384765) on attempt 1: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (19.3833, 19.750730895996092, 75.43147430419921, 82.36444244384765) on attempt 2: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (19.3833, 19.750730895996092, 75.43147430419921, 82.36444244384765) on attempt 3: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Found 0 unique education points.
# Downloading govt_office data for bbox (19.3833, 19.750730895996092, 75.43147430419921, 82.36444244384765)...
# Found 59793 unique govt_office points.
# Downloading highway data for bbox (19.3833, 19.750730895996092, 75.43147430419921, 82.36444244384765)...
# Error downloading amenity data for bbox (19.3833, 19.750730895996092, 75.43147430419921, 82.36444244384765) on attempt 1: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (19.3833, 19.750730895996092, 75.43147430419921, 82.36444244384765) on attempt 2: Expecting value: line 1 column 1 (char 0)
# Error downloading amenity data for bbox (19.3833, 19.750730895996092, 75.43147430419921, 82.36444244384765) on attempt 3: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Found 0 unique highway points.
# Downloading mall data for bbox (19.3833, 19.750730895996092, 75.43147430419921, 82.36444244384765)...
# Found 19820 unique mall points.
# Downloading park data for bbox (19.3833, 19.750730895996092, 75.43147430419921, 82.36444244384765)...
# Error downloading amenity data for bbox (19.3833, 19.750730895996092, 75.43147430419921, 82.36444244384765) on attempt 1: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (19.3833, 19.750730895996092, 75.43147430419921, 82.36444244384765) on attempt 2: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (19.3833, 19.750730895996092, 75.43147430419921, 82.36444244384765) on attempt 3: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Found 0 unique park points.
# Downloading airport data for bbox (19.3833, 19.750730895996092, 75.43147430419921, 82.36444244384765)...
# Found 3880 unique airport points.
#
# Processing chunk 6/91...
# Downloading hospital data for bbox (9.218483352661133, 76.514013671875, 29.648641, 77.72464756)...
# Error downloading amenity data for bbox (9.218483352661133, 76.514013671875, 29.648641, 77.72464756) on attempt 1: Expecting value: line 1 column 1 (char 0)
# Error downloading amenity data for bbox (9.218483352661133, 76.514013671875, 29.648641, 77.72464756) on attempt 2: Expecting value: line 1 column 1 (char 0)
# Found 11482 unique hospital points.
# Downloading public_transport data for bbox (9.218483352661133, 76.514013671875, 29.648641, 77.72464756)...
# Found 10800 unique public_transport points.
# Downloading education data for bbox (9.218483352661133, 76.514013671875, 29.648641, 77.72464756)...
# Error downloading amenity data for bbox (9.218483352661133, 76.514013671875, 29.648641, 77.72464756) on attempt 1: Expecting value: line 1 column 1 (char 0)
# Found 9809 unique education points.
# Downloading govt_office data for bbox (9.218483352661133, 76.514013671875, 29.648641, 77.72464756)...
# Found 2816 unique govt_office points.
# Downloading highway data for bbox (9.218483352661133, 76.514013671875, 29.648641, 77.72464756)...
# Found 110916 unique highway points.
# Downloading mall data for bbox (9.218483352661133, 76.514013671875, 29.648641, 77.72464756)...
# Found 353 unique mall points.
# Downloading park data for bbox (9.218483352661133, 76.514013671875, 29.648641, 77.72464756)...
# Found 9222 unique park points.
# Downloading airport data for bbox (9.218483352661133, 76.514013671875, 29.648641, 77.72464756)...
# Found 25 unique airport points.
#
# Processing chunk 7/91...
# Downloading hospital data for bbox (28.5259173770069, 77.24255793282491, 28.8049318442538, 77.59210114495309)...
# Found 443 unique hospital points.
# Downloading public_transport data for bbox (28.5259173770069, 77.24255793282491, 28.8049318442538, 77.59210114495309)...
# Found 623 unique public_transport points.
# Downloading education data for bbox (28.5259173770069, 77.24255793282491, 28.8049318442538, 77.59210114495309)...
# Found 398 unique education points.
# Downloading govt_office data for bbox (28.5259173770069, 77.24255793282491, 28.8049318442538, 77.59210114495309)...
# Found 40 unique govt_office points.
# Downloading highway data for bbox (28.5259173770069, 77.24255793282491, 28.8049318442538, 77.59210114495309)...
# Found 6116 unique highway points.
# Downloading mall data for bbox (28.5259173770069, 77.24255793282491, 28.8049318442538, 77.59210114495309)...
# Found 37 unique mall points.
# Downloading park data for bbox (28.5259173770069, 77.24255793282491, 28.8049318442538, 77.59210114495309)...
# Found 2154 unique park points.
# Downloading airport data for bbox (28.5259173770069, 77.24255793282491, 28.8049318442538, 77.59210114495309)...
# Found 2 unique airport points.
#
# Processing chunk 8/91...
# Downloading hospital data for bbox (28.1706, 77.12442300000001, 28.8049318442538, 77.68558058922319)...
# Found 1188 unique hospital points.
# Downloading public_transport data for bbox (28.1706, 77.12442300000001, 28.8049318442538, 77.68558058922319)...
# Found 1991 unique public_transport points.
# Downloading education data for bbox (28.1706, 77.12442300000001, 28.8049318442538, 77.68558058922319)...
# Error downloading amenity data for bbox (28.1706, 77.12442300000001, 28.8049318442538, 77.68558058922319) on attempt 1: Expecting value: line 1 column 1 (char 0)
# Error downloading amenity data for bbox (28.1706, 77.12442300000001, 28.8049318442538, 77.68558058922319) on attempt 2: Expecting value: line 1 column 1 (char 0)
# Found 1113 unique education points.
# Downloading govt_office data for bbox (28.1706, 77.12442300000001, 28.8049318442538, 77.68558058922319)...
# Found 183 unique govt_office points.
# Downloading highway data for bbox (28.1706, 77.12442300000001, 28.8049318442538, 77.68558058922319)...
# Found 14551 unique highway points.
# Downloading mall data for bbox (28.1706, 77.12442300000001, 28.8049318442538, 77.68558058922319)...
# Error downloading amenity data for bbox (28.1706, 77.12442300000001, 28.8049318442538, 77.68558058922319) on attempt 1: Expecting value: line 1 column 1 (char 0)
# Found 69 unique mall points.
# Downloading park data for bbox (28.1706, 77.12442300000001, 28.8049318442538, 77.68558058922319)...
# Found 4587 unique park points.
# Downloading airport data for bbox (28.1706, 77.12442300000001, 28.8049318442538, 77.68558058922319)...
# Found 4 unique airport points.
#
# Processing chunk 9/91...
# Downloading hospital data for bbox (28.2903979782804, 77.3262748642862, 28.715887848111002, 77.661036)...
# Found 291 unique hospital points.
# Downloading public_transport data for bbox (28.2903979782804, 77.3262748642862, 28.715887848111002, 77.661036)...
# Found 157 unique public_transport points.
# Downloading education data for bbox (28.2903979782804, 77.3262748642862, 28.715887848111002, 77.661036)...
# Found 244 unique education points.
# Downloading govt_office data for bbox (28.2903979782804, 77.3262748642862, 28.715887848111002, 77.661036)...
# Found 11 unique govt_office points.
# Downloading highway data for bbox (28.2903979782804, 77.3262748642862, 28.715887848111002, 77.661036)...
# Found 5366 unique highway points.
# Downloading mall data for bbox (28.2903979782804, 77.3262748642862, 28.715887848111002, 77.661036)...
# Found 31 unique mall points.
# Downloading park data for bbox (28.2903979782804, 77.3262748642862, 28.715887848111002, 77.661036)...
# Found 1599 unique park points.
# Downloading airport data for bbox (28.2903979782804, 77.3262748642862, 28.715887848111002, 77.661036)...
# Found 2 unique airport points.
#
# Processing chunk 10/91...
# Downloading hospital data for bbox (12.664659881591797, 74.69183959960938, 28.715887848111002, 77.661036)...
# Found 14262 unique hospital points.
# Downloading public_transport data for bbox (12.664659881591797, 74.69183959960938, 28.715887848111002, 77.661036)...
# Found 8517 unique public_transport points.
# Downloading education data for bbox (12.664659881591797, 74.69183959960938, 28.715887848111002, 77.661036)...
# Found 7310 unique education points.
# Downloading govt_office data for bbox (12.664659881591797, 74.69183959960938, 28.715887848111002, 77.661036)...
# Found 1036 unique govt_office points.
# Downloading highway data for bbox (12.664659881591797, 74.69183959960938, 28.715887848111002, 77.661036)...
# Error downloading amenity data for bbox (12.664659881591797, 74.69183959960938, 28.715887848111002, 77.661036) on attempt 1: Expecting value: line 1 column 1 (char 0)
# Found 151662 unique highway points.
# Downloading mall data for bbox (12.664659881591797, 74.69183959960938, 28.715887848111002, 77.661036)...
# Found 317 unique mall points.
# Downloading park data for bbox (12.664659881591797, 74.69183959960938, 28.715887848111002, 77.661036)...
# Found 9289 unique park points.
# Downloading airport data for bbox (12.664659881591797, 74.69183959960938, 28.715887848111002, 77.661036)...
# Found 48 unique airport points.
#
# Processing chunk 11/91...
# Downloading hospital data for bbox (9.5740219, 25.496551, 85.16358899999999, 87.55006399999999)...
# Error downloading amenity data for bbox (9.5740219, 25.496551, 85.16358899999999, 87.55006399999999) on attempt 1: Expecting value: line 1 column 1 (char 0)
# Error downloading amenity data for bbox (9.5740219, 25.496551, 85.16358899999999, 87.55006399999999) on attempt 2: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Found 129939 unique hospital points.
# Downloading public_transport data for bbox (9.5740219, 25.496551, 85.16358899999999, 87.55006399999999)...
# Error downloading amenity data for bbox (9.5740219, 25.496551, 85.16358899999999, 87.55006399999999) on attempt 1: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (9.5740219, 25.496551, 85.16358899999999, 87.55006399999999) on attempt 2: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (9.5740219, 25.496551, 85.16358899999999, 87.55006399999999) on attempt 3: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Found 0 unique public_transport points.
# Downloading education data for bbox (9.5740219, 25.496551, 85.16358899999999, 87.55006399999999)...
# Error downloading amenity data for bbox (9.5740219, 25.496551, 85.16358899999999, 87.55006399999999) on attempt 1: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (9.5740219, 25.496551, 85.16358899999999, 87.55006399999999) on attempt 2: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (9.5740219, 25.496551, 85.16358899999999, 87.55006399999999) on attempt 3: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Found 0 unique education points.
# Downloading govt_office data for bbox (9.5740219, 25.496551, 85.16358899999999, 87.55006399999999)...
# Found 63187 unique govt_office points.
# Downloading highway data for bbox (9.5740219, 25.496551, 85.16358899999999, 87.55006399999999)...
# Error downloading amenity data for bbox (9.5740219, 25.496551, 85.16358899999999, 87.55006399999999) on attempt 1: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (9.5740219, 25.496551, 85.16358899999999, 87.55006399999999) on attempt 2: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (9.5740219, 25.496551, 85.16358899999999, 87.55006399999999) on attempt 3: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Found 0 unique highway points.
# Downloading mall data for bbox (9.5740219, 25.496551, 85.16358899999999, 87.55006399999999)...
# Found 19502 unique mall points.
# Downloading park data for bbox (9.5740219, 25.496551, 85.16358899999999, 87.55006399999999)...
# Error downloading amenity data for bbox (9.5740219, 25.496551, 85.16358899999999, 87.55006399999999) on attempt 1: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (9.5740219, 25.496551, 85.16358899999999, 87.55006399999999) on attempt 2: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (9.5740219, 25.496551, 85.16358899999999, 87.55006399999999) on attempt 3: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Found 0 unique park points.
# Downloading airport data for bbox (9.5740219, 25.496551, 85.16358899999999, 87.55006399999999)...
# Found 3644 unique airport points.
#
# Processing chunk 12/91...
# Downloading hospital data for bbox (17.953261299999998, 72.73807796618041, 28.66669807434082, 86.015316)...
# Error downloading amenity data for bbox (17.953261299999998, 72.73807796618041, 28.66669807434082, 86.015316) on attempt 1: Expecting value: line 1 column 1 (char 0)
# Found 31974 unique hospital points.
# Downloading public_transport data for bbox (17.953261299999998, 72.73807796618041, 28.66669807434082, 86.015316)...
# Error downloading amenity data for bbox (17.953261299999998, 72.73807796618041, 28.66669807434082, 86.015316) on attempt 1: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (17.953261299999998, 72.73807796618041, 28.66669807434082, 86.015316) on attempt 2: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (17.953261299999998, 72.73807796618041, 28.66669807434082, 86.015316) on attempt 3: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Found 0 unique public_transport points.
# Downloading education data for bbox (17.953261299999998, 72.73807796618041, 28.66669807434082, 86.015316)...
# Found 26932 unique education points.
# Downloading govt_office data for bbox (17.953261299999998, 72.73807796618041, 28.66669807434082, 86.015316)...
# Found 3496 unique govt_office points.
# Downloading highway data for bbox (17.953261299999998, 72.73807796618041, 28.66669807434082, 86.015316)...
# Found 345992 unique highway points.
# Downloading mall data for bbox (17.953261299999998, 72.73807796618041, 28.66669807434082, 86.015316)...
# Found 777 unique mall points.
# Downloading park data for bbox (17.953261299999998, 72.73807796618041, 28.66669807434082, 86.015316)...
# Found 14506 unique park points.
# Downloading airport data for bbox (17.953261299999998, 72.73807796618041, 28.66669807434082, 86.015316)...
# Found 193 unique airport points.
#
# Processing chunk 13/91...
# Downloading hospital data for bbox (9.323534, 76.29844200000001, 28.729605154155323, 85.57952944595229)...
# Found 38980 unique hospital points.
# Downloading public_transport data for bbox (9.323534, 76.29844200000001, 28.729605154155323, 85.57952944595229)...
# Error downloading amenity data for bbox (9.323534, 76.29844200000001, 28.729605154155323, 85.57952944595229) on attempt 1: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (9.323534, 76.29844200000001, 28.729605154155323, 85.57952944595229) on attempt 2: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (9.323534, 76.29844200000001, 28.729605154155323, 85.57952944595229) on attempt 3: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Found 0 unique public_transport points.
# Downloading education data for bbox (9.323534, 76.29844200000001, 28.729605154155323, 85.57952944595229)...
# Error downloading amenity data for bbox (9.323534, 76.29844200000001, 28.729605154155323, 85.57952944595229) on attempt 1: Expecting value: line 1 column 1 (char 0)
# Found 38640 unique education points.
# Downloading govt_office data for bbox (9.323534, 76.29844200000001, 28.729605154155323, 85.57952944595229)...
# Found 7694 unique govt_office points.
# Downloading highway data for bbox (9.323534, 76.29844200000001, 28.729605154155323, 85.57952944595229)...
# Error downloading amenity data for bbox (9.323534, 76.29844200000001, 28.729605154155323, 85.57952944595229) on attempt 1: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Found 410104 unique highway points.
# Downloading mall data for bbox (9.323534, 76.29844200000001, 28.729605154155323, 85.57952944595229)...
# Error downloading amenity data for bbox (9.323534, 76.29844200000001, 28.729605154155323, 85.57952944595229) on attempt 1: Expecting value: line 1 column 1 (char 0)
# Found 1082 unique mall points.
# Downloading park data for bbox (9.323534, 76.29844200000001, 28.729605154155323, 85.57952944595229)...
# Found 16704 unique park points.
# Downloading airport data for bbox (9.323534, 76.29844200000001, 28.729605154155323, 85.57952944595229)...
# Found 180 unique airport points.
#
# Processing chunk 14/91...
# Downloading hospital data for bbox (8.0298754, 73.70593554511021, 28.734178161621102, 93.59023909999999)...
# Found 63941 unique hospital points.
# Downloading public_transport data for bbox (8.0298754, 73.70593554511021, 28.734178161621102, 93.59023909999999)...
# Error downloading amenity data for bbox (8.0298754, 73.70593554511021, 28.734178161621102, 93.59023909999999) on attempt 1: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (8.0298754, 73.70593554511021, 28.734178161621102, 93.59023909999999) on attempt 2: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (8.0298754, 73.70593554511021, 28.734178161621102, 93.59023909999999) on attempt 3: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Found 0 unique public_transport points.
# Downloading education data for bbox (8.0298754, 73.70593554511021, 28.734178161621102, 93.59023909999999)...
# Found 72804 unique education points.
# Downloading govt_office data for bbox (8.0298754, 73.70593554511021, 28.734178161621102, 93.59023909999999)...
# Error downloading amenity data for bbox (8.0298754, 73.70593554511021, 28.734178161621102, 93.59023909999999) on attempt 1: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Found 17849 unique govt_office points.
# Downloading highway data for bbox (8.0298754, 73.70593554511021, 28.734178161621102, 93.59023909999999)...
# Error downloading amenity data for bbox (8.0298754, 73.70593554511021, 28.734178161621102, 93.59023909999999) on attempt 1: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (8.0298754, 73.70593554511021, 28.734178161621102, 93.59023909999999) on attempt 2: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (8.0298754, 73.70593554511021, 28.734178161621102, 93.59023909999999) on attempt 3: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Found 0 unique highway points.
# Downloading mall data for bbox (8.0298754, 73.70593554511021, 28.734178161621102, 93.59023909999999)...
# Found 2513 unique mall points.
# Downloading park data for bbox (8.0298754, 73.70593554511021, 28.734178161621102, 93.59023909999999)...
# Error downloading amenity data for bbox (8.0298754, 73.70593554511021, 28.734178161621102, 93.59023909999999) on attempt 1: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (8.0298754, 73.70593554511021, 28.734178161621102, 93.59023909999999) on attempt 2: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (8.0298754, 73.70593554511021, 28.734178161621102, 93.59023909999999) on attempt 3: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Found 0 unique park points.
# Downloading airport data for bbox (8.0298754, 73.70593554511021, 28.734178161621102, 93.59023909999999)...
# Found 360 unique airport points.
#
# Processing chunk 15/91...
# Downloading hospital data for bbox (28.331867785361403, 77.215412, 28.717427637006363, 77.58560123301231)...
# Found 771 unique hospital points.
# Downloading public_transport data for bbox (28.331867785361403, 77.215412, 28.717427637006363, 77.58560123301231)...
# Found 1125 unique public_transport points.
# Downloading education data for bbox (28.331867785361403, 77.215412, 28.717427637006363, 77.58560123301231)...
# Found 665 unique education points.
# Downloading govt_office data for bbox (28.331867785361403, 77.215412, 28.717427637006363, 77.58560123301231)...
# Found 114 unique govt_office points.
# Downloading highway data for bbox (28.331867785361403, 77.215412, 28.717427637006363, 77.58560123301231)...
# Found 9271 unique highway points.
# Downloading mall data for bbox (28.331867785361403, 77.215412, 28.717427637006363, 77.58560123301231)...
# Found 54 unique mall points.
# Downloading park data for bbox (28.331867785361403, 77.215412, 28.717427637006363, 77.58560123301231)...
# Found 3303 unique park points.
# Downloading airport data for bbox (28.331867785361403, 77.215412, 28.717427637006363, 77.58560123301231)...
# Found 2 unique airport points.
#
# Processing chunk 16/91...
# Downloading hospital data for bbox (28.331867785361403, 77.215412, 28.717427637006363, 77.58560123301231)...
# Found 771 unique hospital points.
# Downloading public_transport data for bbox (28.331867785361403, 77.215412, 28.717427637006363, 77.58560123301231)...
# Found 1125 unique public_transport points.
# Downloading education data for bbox (28.331867785361403, 77.215412, 28.717427637006363, 77.58560123301231)...
# Found 665 unique education points.
# Downloading govt_office data for bbox (28.331867785361403, 77.215412, 28.717427637006363, 77.58560123301231)...
# Found 114 unique govt_office points.
# Downloading highway data for bbox (28.331867785361403, 77.215412, 28.717427637006363, 77.58560123301231)...
# Found 9271 unique highway points.
# Downloading mall data for bbox (28.331867785361403, 77.215412, 28.717427637006363, 77.58560123301231)...
# Found 54 unique mall points.
# Downloading park data for bbox (28.331867785361403, 77.215412, 28.717427637006363, 77.58560123301231)...
# Found 3303 unique park points.
# Downloading airport data for bbox (28.331867785361403, 77.215412, 28.717427637006363, 77.58560123301231)...
# Found 2 unique airport points.
#
# Processing chunk 17/91...
# Downloading hospital data for bbox (11.123089, 75.6535662, 28.717427637006363, 82.87381429999999)...
# Found 33058 unique hospital points.
# Downloading public_transport data for bbox (11.123089, 75.6535662, 28.717427637006363, 82.87381429999999)...
# Error downloading amenity data for bbox (11.123089, 75.6535662, 28.717427637006363, 82.87381429999999) on attempt 1: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (11.123089, 75.6535662, 28.717427637006363, 82.87381429999999) on attempt 2: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (11.123089, 75.6535662, 28.717427637006363, 82.87381429999999) on attempt 3: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Found 0 unique public_transport points.
# Downloading education data for bbox (11.123089, 75.6535662, 28.717427637006363, 82.87381429999999)...
# Found 21120 unique education points.
# Downloading govt_office data for bbox (11.123089, 75.6535662, 28.717427637006363, 82.87381429999999)...
# Found 4280 unique govt_office points.
# Downloading highway data for bbox (11.123089, 75.6535662, 28.717427637006363, 82.87381429999999)...
# Error downloading amenity data for bbox (11.123089, 75.6535662, 28.717427637006363, 82.87381429999999) on attempt 1: Expecting value: line 1 column 1 (char 0)
# Found 342946 unique highway points.
# Downloading mall data for bbox (11.123089, 75.6535662, 28.717427637006363, 82.87381429999999)...
# Found 804 unique mall points.
# Downloading park data for bbox (11.123089, 75.6535662, 28.717427637006363, 82.87381429999999)...
# Found 15685 unique park points.
# Downloading airport data for bbox (11.123089, 75.6535662, 28.717427637006363, 82.87381429999999)...
# Found 133 unique airport points.
#
# Processing chunk 18/91...
# Downloading hospital data for bbox (8.853878408525791, 72.64347686767579, 29.236699, 80.13106753999999)...
# Found 49190 unique hospital points.
# Downloading public_transport data for bbox (8.853878408525791, 72.64347686767579, 29.236699, 80.13106753999999)...
# Error downloading amenity data for bbox (8.853878408525791, 72.64347686767579, 29.236699, 80.13106753999999) on attempt 1: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (8.853878408525791, 72.64347686767579, 29.236699, 80.13106753999999) on attempt 2: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (8.853878408525791, 72.64347686767579, 29.236699, 80.13106753999999) on attempt 3: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Found 0 unique public_transport points.
# Downloading education data for bbox (8.853878408525791, 72.64347686767579, 29.236699, 80.13106753999999)...
# Found 33912 unique education points.
# Downloading govt_office data for bbox (8.853878408525791, 72.64347686767579, 29.236699, 80.13106753999999)...
# Found 10804 unique govt_office points.
# Downloading highway data for bbox (8.853878408525791, 72.64347686767579, 29.236699, 80.13106753999999)...
# Found 459303 unique highway points.
# Downloading mall data for bbox (8.853878408525791, 72.64347686767579, 29.236699, 80.13106753999999)...
# Found 1444 unique mall points.
# Downloading park data for bbox (8.853878408525791, 72.64347686767579, 29.236699, 80.13106753999999)...
# Found 19176 unique park points.
# Downloading airport data for bbox (8.853878408525791, 72.64347686767579, 29.236699, 80.13106753999999)...
# Found 155 unique airport points.
#
# Processing chunk 19/91...
# Downloading hospital data for bbox (18.6949214, 72.753888, 19.28436813354492, 73.43726863607539)...
# Error downloading amenity data for bbox (18.6949214, 72.753888, 19.28436813354492, 73.43726863607539) on attempt 1: Expecting value: line 1 column 1 (char 0)
# Found 2178 unique hospital points.
# Downloading public_transport data for bbox (18.6949214, 72.753888, 19.28436813354492, 73.43726863607539)...
# Found 2847 unique public_transport points.
# Downloading education data for bbox (18.6949214, 72.753888, 19.28436813354492, 73.43726863607539)...
# Found 1019 unique education points.
# Downloading govt_office data for bbox (18.6949214, 72.753888, 19.28436813354492, 73.43726863607539)...
# Found 124 unique govt_office points.
# Downloading highway data for bbox (18.6949214, 72.753888, 19.28436813354492, 73.43726863607539)...
# Found 13840 unique highway points.
# Downloading mall data for bbox (18.6949214, 72.753888, 19.28436813354492, 73.43726863607539)...
# Found 80 unique mall points.
# Downloading park data for bbox (18.6949214, 72.753888, 19.28436813354492, 73.43726863607539)...
# Found 1892 unique park points.
# Downloading airport data for bbox (18.6949214, 72.753888, 19.28436813354492, 73.43726863607539)...
# Found 5 unique airport points.
#
# Processing chunk 20/91...
# Downloading hospital data for bbox (18.8668540827317, 72.89339689514861, 19.260910345383703, 73.23349187999999)...
# Found 1011 unique hospital points.
# Downloading public_transport data for bbox (18.8668540827317, 72.89339689514861, 19.260910345383703, 73.23349187999999)...
# Found 1635 unique public_transport points.
# Downloading education data for bbox (18.8668540827317, 72.89339689514861, 19.260910345383703, 73.23349187999999)...
# Found 455 unique education points.
# Downloading govt_office data for bbox (18.8668540827317, 72.89339689514861, 19.260910345383703, 73.23349187999999)...
# Found 53 unique govt_office points.
# Downloading highway data for bbox (18.8668540827317, 72.89339689514861, 19.260910345383703, 73.23349187999999)...
# Found 6336 unique highway points.
# Downloading mall data for bbox (18.8668540827317, 72.89339689514861, 19.260910345383703, 73.23349187999999)...
# Found 40 unique mall points.
# Downloading park data for bbox (18.8668540827317, 72.89339689514861, 19.260910345383703, 73.23349187999999)...
# Found 961 unique park points.
# Downloading airport data for bbox (18.8668540827317, 72.89339689514861, 19.260910345383703, 73.23349187999999)...
# Found 1 unique airport points.
#
# Processing chunk 21/91...
# Downloading hospital data for bbox (18.8668540827317, 72.89339689514861, 19.260910345383703, 73.23349187999999)...
# Found 1011 unique hospital points.
# Downloading public_transport data for bbox (18.8668540827317, 72.89339689514861, 19.260910345383703, 73.23349187999999)...
# Found 1635 unique public_transport points.
# Downloading education data for bbox (18.8668540827317, 72.89339689514861, 19.260910345383703, 73.23349187999999)...
# Found 455 unique education points.
# Downloading govt_office data for bbox (18.8668540827317, 72.89339689514861, 19.260910345383703, 73.23349187999999)...
# Found 53 unique govt_office points.
# Downloading highway data for bbox (18.8668540827317, 72.89339689514861, 19.260910345383703, 73.23349187999999)...
# Found 6336 unique highway points.
# Downloading mall data for bbox (18.8668540827317, 72.89339689514861, 19.260910345383703, 73.23349187999999)...
# Found 40 unique mall points.
# Downloading park data for bbox (18.8668540827317, 72.89339689514861, 19.260910345383703, 73.23349187999999)...
# Found 961 unique park points.
# Downloading airport data for bbox (18.8668540827317, 72.89339689514861, 19.260910345383703, 73.23349187999999)...
# Found 1 unique airport points.
#
# Processing chunk 22/91...
# Downloading hospital data for bbox (8.223376, 8.443328000000001, 27.821976000000003, 78.92798767089843)...
# Found 55817 unique hospital points.
# Downloading public_transport data for bbox (8.223376, 8.443328000000001, 27.821976000000003, 78.92798767089843)...
# Error downloading amenity data for bbox (8.223376, 8.443328000000001, 27.821976000000003, 78.92798767089843) on attempt 1: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (8.223376, 8.443328000000001, 27.821976000000003, 78.92798767089843) on attempt 2: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (8.223376, 8.443328000000001, 27.821976000000003, 78.92798767089843) on attempt 3: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Found 0 unique public_transport points.
# Downloading education data for bbox (8.223376, 8.443328000000001, 27.821976000000003, 78.92798767089843)...
# Found 49106 unique education points.
# Downloading govt_office data for bbox (8.223376, 8.443328000000001, 27.821976000000003, 78.92798767089843)...
# Found 15358 unique govt_office points.
# Downloading highway data for bbox (8.223376, 8.443328000000001, 27.821976000000003, 78.92798767089843)...
# Error downloading amenity data for bbox (8.223376, 8.443328000000001, 27.821976000000003, 78.92798767089843) on attempt 1: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (8.223376, 8.443328000000001, 27.821976000000003, 78.92798767089843) on attempt 2: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (8.223376, 8.443328000000001, 27.821976000000003, 78.92798767089843) on attempt 3: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Found 0 unique highway points.
# Downloading mall data for bbox (8.223376, 8.443328000000001, 27.821976000000003, 78.92798767089843)...
# Found 2811 unique mall points.
# Downloading park data for bbox (8.223376, 8.443328000000001, 27.821976000000003, 78.92798767089843)...
# Found 20981 unique park points.
# Downloading airport data for bbox (8.223376, 8.443328000000001, 27.821976000000003, 78.92798767089843)...
# Found 899 unique airport points.
#
# Processing chunk 23/91...
# Downloading hospital data for bbox (8.248514, 8.443328285217286, 27.37356, 83.562587)...
# Found 68812 unique hospital points.
# Downloading public_transport data for bbox (8.248514, 8.443328285217286, 27.37356, 83.562587)...
# Error downloading amenity data for bbox (8.248514, 8.443328285217286, 27.37356, 83.562587) on attempt 1: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (8.248514, 8.443328285217286, 27.37356, 83.562587) on attempt 2: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (8.248514, 8.443328285217286, 27.37356, 83.562587) on attempt 3: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Found 0 unique public_transport points.
# Downloading education data for bbox (8.248514, 8.443328285217286, 27.37356, 83.562587)...
# Found 55543 unique education points.
# Downloading govt_office data for bbox (8.248514, 8.443328285217286, 27.37356, 83.562587)...
# Found 16608 unique govt_office points.
# Downloading highway data for bbox (8.248514, 8.443328285217286, 27.37356, 83.562587)...
# Error downloading amenity data for bbox (8.248514, 8.443328285217286, 27.37356, 83.562587) on attempt 1: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (8.248514, 8.443328285217286, 27.37356, 83.562587) on attempt 2: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (8.248514, 8.443328285217286, 27.37356, 83.562587) on attempt 3: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Found 0 unique highway points.
# Downloading mall data for bbox (8.248514, 8.443328285217286, 27.37356, 83.562587)...
# Found 3064 unique mall points.
# Downloading park data for bbox (8.248514, 8.443328285217286, 27.37356, 83.562587)...
# Found 24772 unique park points.
# Downloading airport data for bbox (8.248514, 8.443328285217286, 27.37356, 83.562587)...
# Found 962 unique airport points.
#
# Processing chunk 24/91...
# Downloading hospital data for bbox (9.77497905089424, 76.102659, 18.14656, 83.547162)...
# Found 22055 unique hospital points.
# Downloading public_transport data for bbox (9.77497905089424, 76.102659, 18.14656, 83.547162)...
# Found 18755 unique public_transport points.
# Downloading education data for bbox (9.77497905089424, 76.102659, 18.14656, 83.547162)...
# Found 16769 unique education points.
# Downloading govt_office data for bbox (9.77497905089424, 76.102659, 18.14656, 83.547162)...
# Found 4924 unique govt_office points.
# Downloading highway data for bbox (9.77497905089424, 76.102659, 18.14656, 83.547162)...
# Found 193379 unique highway points.
# Downloading mall data for bbox (9.77497905089424, 76.102659, 18.14656, 83.547162)...
# Found 695 unique mall points.
# Downloading park data for bbox (9.77497905089424, 76.102659, 18.14656, 83.547162)...
# Found 6108 unique park points.
# Downloading airport data for bbox (9.77497905089424, 76.102659, 18.14656, 83.547162)...
# Found 46 unique airport points.
#
# Processing chunk 25/91...
# Downloading hospital data for bbox (12.02269, 72.54772000000001, 28.573383492685302, 83.547162)...
# Found 45454 unique hospital points.
# Downloading public_transport data for bbox (12.02269, 72.54772000000001, 28.573383492685302, 83.547162)...
# Error downloading amenity data for bbox (12.02269, 72.54772000000001, 28.573383492685302, 83.547162) on attempt 1: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (12.02269, 72.54772000000001, 28.573383492685302, 83.547162) on attempt 2: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (12.02269, 72.54772000000001, 28.573383492685302, 83.547162) on attempt 3: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Found 0 unique public_transport points.
# Downloading education data for bbox (12.02269, 72.54772000000001, 28.573383492685302, 83.547162)...
# Found 24615 unique education points.
# Downloading govt_office data for bbox (12.02269, 72.54772000000001, 28.573383492685302, 83.547162)...
# Found 4010 unique govt_office points.
# Downloading highway data for bbox (12.02269, 72.54772000000001, 28.573383492685302, 83.547162)...
# Found 465208 unique highway points.
# Downloading mall data for bbox (12.02269, 72.54772000000001, 28.573383492685302, 83.547162)...
# Found 1028 unique mall points.
# Downloading park data for bbox (12.02269, 72.54772000000001, 28.573383492685302, 83.547162)...
# Found 17013 unique park points.
# Downloading airport data for bbox (12.02269, 72.54772000000001, 28.573383492685302, 83.547162)...
# Found 190 unique airport points.
#
# Processing chunk 26/91...
# Downloading hospital data for bbox (2.167379, 70.69325, 26.940387, 75.91533299999999)...
# Found 19671 unique hospital points.
# Downloading public_transport data for bbox (2.167379, 70.69325, 26.940387, 75.91533299999999)...
# Found 8160 unique public_transport points.
# Downloading education data for bbox (2.167379, 70.69325, 26.940387, 75.91533299999999)...
# Found 8729 unique education points.
# Downloading govt_office data for bbox (2.167379, 70.69325, 26.940387, 75.91533299999999)...
# Found 2473 unique govt_office points.
# Downloading highway data for bbox (2.167379, 70.69325, 26.940387, 75.91533299999999)...
# Found 169796 unique highway points.
# Downloading mall data for bbox (2.167379, 70.69325, 26.940387, 75.91533299999999)...
# Found 403 unique mall points.
# Downloading park data for bbox (2.167379, 70.69325, 26.940387, 75.91533299999999)...
# Found 5944 unique park points.
# Downloading airport data for bbox (2.167379, 70.69325, 26.940387, 75.91533299999999)...
# Found 87 unique airport points.
#
# Processing chunk 27/91...
# Downloading hospital data for bbox (2.167379, 70.69325, 26.940387, 75.91533299999999)...
# Found 19671 unique hospital points.
# Downloading public_transport data for bbox (2.167379, 70.69325, 26.940387, 75.91533299999999)...
# Found 8160 unique public_transport points.
# Downloading education data for bbox (2.167379, 70.69325, 26.940387, 75.91533299999999)...
# Found 8729 unique education points.
# Downloading govt_office data for bbox (2.167379, 70.69325, 26.940387, 75.91533299999999)...
# Found 2473 unique govt_office points.
# Downloading highway data for bbox (2.167379, 70.69325, 26.940387, 75.91533299999999)...
# Found 169796 unique highway points.
# Downloading mall data for bbox (2.167379, 70.69325, 26.940387, 75.91533299999999)...
# Found 403 unique mall points.
# Downloading park data for bbox (2.167379, 70.69325, 26.940387, 75.91533299999999)...
# Found 5944 unique park points.
# Downloading airport data for bbox (2.167379, 70.69325, 26.940387, 75.91533299999999)...
# Found 87 unique airport points.
#
# Processing chunk 28/91...
# Downloading hospital data for bbox (14.892193, 73.017995, 26.302227000000002, 91.947463)...
# Found 34126 unique hospital points.
# Downloading public_transport data for bbox (14.892193, 73.017995, 26.302227000000002, 91.947463)...
# Error downloading amenity data for bbox (14.892193, 73.017995, 26.302227000000002, 91.947463) on attempt 1: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (14.892193, 73.017995, 26.302227000000002, 91.947463) on attempt 2: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Error downloading amenity data for bbox (14.892193, 73.017995, 26.302227000000002, 91.947463) on attempt 3: HTTPSConnectionPool(host='overpass-api.de', port=443): Read timed out. (read timeout=60)
# Found 0 unique public_transport points.
# Downloading education data for bbox (14.892193, 73.017995, 26.302227000000002, 91.947463)...
# Found 20427 unique education points.
# Downloading govt_office data for bbox (14.892193, 73.017995, 26.302227000000002, 91.947463)...
# Found 4236 unique govt_office points.
# Downloading highway data for bbox (14.892193, 73.017995, 26.302227000000002, 91.947463)...
# Found 395764 unique highway points.
# Downloading mall data for bbox (14.892193, 73.017995, 26.302227000000002, 91.947463)...
# Found 1337 unique mall points.
# Downloading park data for bbox (14.892193, 73.017995, 26.302227000000002, 91.947463)...
# Found 10559 unique park points.
# ...
# Found 2027 unique public_transport points.
# Downloading education data for bbox (18.7305523, 72.8568656970685, 19.3575583, 73.3846445)...
# Found 587 unique education points.
# Downloading govt_office data for bbox (18.7305523, 72.8568656970685, 19.3575583, 73.3846445)...
# Found 68 unique govt_office points.
# Downloading highway data for bbox (18.7305523, 72.8568656970685, 19.3575583, 73.3846445)...
# Found 9586 unique highway points.
# Downloading mall data for bbox (18.7305523, 72.8568656970685, 19.3575583, 73.3846445)...
# Found 51 unique mall points.
# Downloading park data for bbox (18.7305523, 72.8568656970685, 19.3575583, 73.3846445)...
# Found 1420 unique park points.
# Downloading airport data for bbox (18.7305523, 72.8568656970685, 19.3575583, 73.3846445)...
# Found 3 unique airport points.
#
# Processing chunk 79/91...
# Downloading hospital data for bbox (18.7305523, 72.8568656970685, 19.3575583, 73.3846445)...
# Found 1467 unique hospital points.
# Downloading public_transport data for bbox (18.7305523, 72.8568656970685, 19.3575583, 73.3846445)...
# Found 2027 unique public_transport points.
# Downloading education data for bbox (18.7305523, 72.8568656970685, 19.3575583, 73.3846445)...
# Found 587 unique education points.
# Downloading govt_office data for bbox (18.7305523, 72.8568656970685, 19.3575583, 73.3846445)...
# Found 68 unique govt_office points.
# Downloading highway data for bbox (18.7305523, 72.8568656970685, 19.3575583, 73.3846445)...
# Found 9586 unique highway points.
# Downloading mall data for bbox (18.7305523, 72.8568656970685, 19.3575583, 73.3846445)...
# Found 51 unique mall points.
# Downloading park data for bbox (18.7305523, 72.8568656970685, 19.3575583, 73.3846445)...
# Found 1420 unique park points.
# Downloading airport data for bbox (18.7305523, 72.8568656970685, 19.3575583, 73.3846445)...
# Found 3 unique airport points.
#
# Processing chunk 80/91...
# Downloading hospital data for bbox (18.7305523, 72.8568656970685, 19.3575583, 73.3846445)...
# Found 1467 unique hospital points.
# Downloading public_transport data for bbox (18.7305523, 72.8568656970685, 19.3575583, 73.3846445)...
# Found 2027 unique public_transport points.
# Downloading education data for bbox (18.7305523, 72.8568656970685, 19.3575583, 73.3846445)...
# Found 587 unique education points.
# Downloading govt_office data for bbox (18.7305523, 72.8568656970685, 19.3575583, 73.3846445)...
# Found 68 unique govt_office points.
# Downloading highway data for bbox (18.7305523, 72.8568656970685, 19.3575583, 73.3846445)...
# Found 9586 unique highway points.
# Downloading mall data for bbox (18.7305523, 72.8568656970685, 19.3575583, 73.3846445)...
# Found 51 unique mall points.
# Downloading park data for bbox (18.7305523, 72.8568656970685, 19.3575583, 73.3846445)...
# Found 1420 unique park points.
# Downloading airport data for bbox (18.7305523, 72.8568656970685, 19.3575583, 73.3846445)...
# Found 3 unique airport points.
#
# Processing chunk 81/91...
# Downloading hospital data for bbox (17.2969314, 72.8568656970685, 28.9619976043701, 78.48607025146484)...
# Found 20134 unique hospital points.
# Downloading public_transport data for bbox (17.2969314, 72.8568656970685, 28.9619976043701, 78.48607025146484)...
# Found 8119 unique public_transport points.
# Downloading education data for bbox (17.2969314, 72.8568656970685, 28.9619976043701, 78.48607025146484)...
# Found 6264 unique education points.
# Downloading govt_office data for bbox (17.2969314, 72.8568656970685, 28.9619976043701, 78.48607025146484)...
# Found 987 unique govt_office points.
# Downloading highway data for bbox (17.2969314, 72.8568656970685, 28.9619976043701, 78.48607025146484)...
# Found 200124 unique highway points.
# Downloading mall data for bbox (17.2969314, 72.8568656970685, 28.9619976043701, 78.48607025146484)...
# Found 499 unique mall points.
# Downloading park data for bbox (17.2969314, 72.8568656970685, 28.9619976043701, 78.48607025146484)...
# Found 12246 unique park points.
# Downloading airport data for bbox (17.2969314, 72.8568656970685, 28.9619976043701, 78.48607025146484)...
# Found 74 unique airport points.
#
# Processing chunk 82/91...
# Downloading hospital data for bbox (22.359440231323237, 76.8828126032795, 28.948325959817602, 88.47885284423828)...
# Found 14391 unique hospital points.
# Downloading public_transport data for bbox (22.359440231323237, 76.8828126032795, 28.948325959817602, 88.47885284423828)...
# Found 7743 unique public_transport points.
# Downloading education data for bbox (22.359440231323237, 76.8828126032795, 28.948325959817602, 88.47885284423828)...
# Found 28171 unique education points.
# Downloading govt_office data for bbox (22.359440231323237, 76.8828126032795, 28.948325959817602, 88.47885284423828)...
# Found 3364 unique govt_office points.
# Downloading highway data for bbox (22.359440231323237, 76.8828126032795, 28.948325959817602, 88.47885284423828)...
# Found 188022 unique highway points.
# Downloading mall data for bbox (22.359440231323237, 76.8828126032795, 28.948325959817602, 88.47885284423828)...
# Found 450 unique mall points.
# Downloading park data for bbox (22.359440231323237, 76.8828126032795, 28.948325959817602, 88.47885284423828)...
# Found 12337 unique park points.
# Downloading airport data for bbox (22.359440231323237, 76.8828126032795, 28.948325959817602, 88.47885284423828)...
# Found 146 unique airport points.
#
# Processing chunk 83/91...
# Downloading hospital data for bbox (28.370099534290407, 76.93622198610521, 28.829756900000003, 77.3828814979278)...
# Found 1526 unique hospital points.
# Downloading public_transport data for bbox (28.370099534290407, 76.93622198610521, 28.829756900000003, 77.3828814979278)...
# Found 2327 unique public_transport points.
# Downloading education data for bbox (28.370099534290407, 76.93622198610521, 28.829756900000003, 77.3828814979278)...
# Found 1472 unique education points.
# Downloading govt_office data for bbox (28.370099534290407, 76.93622198610521, 28.829756900000003, 77.3828814979278)...
# Found 234 unique govt_office points.
# Downloading highway data for bbox (28.370099534290407, 76.93622198610521, 28.829756900000003, 77.3828814979278)...
# Found 13971 unique highway points.
# Downloading mall data for bbox (28.370099534290407, 76.93622198610521, 28.829756900000003, 77.3828814979278)...
# Found 106 unique mall points.
# Downloading park data for bbox (28.370099534290407, 76.93622198610521, 28.829756900000003, 77.3828814979278)...
# Found 5172 unique park points.
# Downloading airport data for bbox (28.370099534290407, 76.93622198610521, 28.829756900000003, 77.3828814979278)...
# Found 4 unique airport points.
#
# Processing chunk 84/91...
# Downloading hospital data for bbox (28.370099534290407, 76.93622198610521, 28.829756900000003, 77.3828814979278)...
# Found 1526 unique hospital points.
# Downloading public_transport data for bbox (28.370099534290407, 76.93622198610521, 28.829756900000003, 77.3828814979278)...
# Found 2327 unique public_transport points.
# Downloading education data for bbox (28.370099534290407, 76.93622198610521, 28.829756900000003, 77.3828814979278)...
# Found 1472 unique education points.
# Downloading govt_office data for bbox (28.370099534290407, 76.93622198610521, 28.829756900000003, 77.3828814979278)...
# Found 234 unique govt_office points.
# Downloading highway data for bbox (28.370099534290407, 76.93622198610521, 28.829756900000003, 77.3828814979278)...
# Found 13971 unique highway points.
# Downloading mall data for bbox (28.370099534290407, 76.93622198610521, 28.829756900000003, 77.3828814979278)...
# Found 106 unique mall points.
# Downloading park data for bbox (28.370099534290407, 76.93622198610521, 28.829756900000003, 77.3828814979278)...
# Found 5172 unique park points.
# Downloading airport data for bbox (28.370099534290407, 76.93622198610521, 28.829756900000003, 77.3828814979278)...
# Found 4 unique airport points.
#
# Processing chunk 85/91...
# Downloading hospital data for bbox (28.370099534290407, 76.93622198610521, 28.829756900000003, 77.3828814979278)...
# Found 1526 unique hospital points.
# Downloading public_transport data for bbox (28.370099534290407, 76.93622198610521, 28.829756900000003, 77.3828814979278)...
# Found 2327 unique public_transport points.
# Downloading education data for bbox (28.370099534290407, 76.93622198610521, 28.829756900000003, 77.3828814979278)...
# Found 1472 unique education points.
# Downloading govt_office data for bbox (28.370099534290407, 76.93622198610521, 28.829756900000003, 77.3828814979278)...
# Found 234 unique govt_office points.
# Downloading highway data for bbox (28.370099534290407, 76.93622198610521, 28.829756900000003, 77.3828814979278)...
# Found 13971 unique highway points.
# Downloading mall data for bbox (28.370099534290407, 76.93622198610521, 28.829756900000003, 77.3828814979278)...
# Found 106 unique mall points.
# Downloading park data for bbox (28.370099534290407, 76.93622198610521, 28.829756900000003, 77.3828814979278)...
# Found 5172 unique park points.
# Downloading airport data for bbox (28.370099534290407, 76.93622198610521, 28.829756900000003, 77.3828814979278)...
# Found 4 unique airport points.
#
# Processing chunk 86/91...
# Downloading hospital data for bbox (12.279926681518557, 76.93622198610521, 28.829756900000003, 80.4190286981945)...
# Found 18687 unique hospital points.
# Downloading public_transport data for bbox (12.279926681518557, 76.93622198610521, 28.829756900000003, 80.4190286981945)...
# Found 12338 unique public_transport points.
# Downloading education data for bbox (12.279926681518557, 76.93622198610521, 28.829756900000003, 80.4190286981945)...
# Found 9925 unique education points.
# Downloading govt_office data for bbox (12.279926681518557, 76.93622198610521, 28.829756900000003, 80.4190286981945)...
# Found 1707 unique govt_office points.
# Downloading highway data for bbox (12.279926681518557, 76.93622198610521, 28.829756900000003, 80.4190286981945)...
# Found 195425 unique highway points.
# Downloading mall data for bbox (12.279926681518557, 76.93622198610521, 28.829756900000003, 80.4190286981945)...
# Found 510 unique mall points.
# Downloading park data for bbox (12.279926681518557, 76.93622198610521, 28.829756900000003, 80.4190286981945)...
# Found 11452 unique park points.
# Downloading airport data for bbox (12.279926681518557, 76.93622198610521, 28.829756900000003, 80.4190286981945)...
# Found 61 unique airport points.
#
# Processing chunk 87/91...
# Downloading hospital data for bbox (12.279926681518557, 78.3888189, 17.5468116, 80.4033726475907)...
# Found 5925 unique hospital points.
# Downloading public_transport data for bbox (12.279926681518557, 78.3888189, 17.5468116, 80.4033726475907)...
# Found 3241 unique public_transport points.
# Downloading education data for bbox (12.279926681518557, 78.3888189, 17.5468116, 80.4033726475907)...
# Found 2927 unique education points.
# Downloading govt_office data for bbox (12.279926681518557, 78.3888189, 17.5468116, 80.4033726475907)...
# Found 459 unique govt_office points.
# Downloading highway data for bbox (12.279926681518557, 78.3888189, 17.5468116, 80.4033726475907)...
# Found 45304 unique highway points.
# Downloading mall data for bbox (12.279926681518557, 78.3888189, 17.5468116, 80.4033726475907)...
# Found 162 unique mall points.
# Downloading park data for bbox (12.279926681518557, 78.3888189, 17.5468116, 80.4033726475907)...
# Found 1745 unique park points.
# Downloading airport data for bbox (12.279926681518557, 78.3888189, 17.5468116, 80.4033726475907)...
# Found 12 unique airport points.
#
# Processing chunk 88/91...
# Downloading hospital data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 1631 unique hospital points.
# Downloading public_transport data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 1316 unique public_transport points.
# Downloading education data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 957 unique education points.
# Downloading govt_office data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 145 unique govt_office points.
# Downloading highway data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 8499 unique highway points.
# Downloading mall data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 23 unique mall points.
# Downloading park data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 528 unique park points.
# Downloading airport data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 3 unique airport points.
#
# Processing chunk 89/91...
# Downloading hospital data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 1631 unique hospital points.
# Downloading public_transport data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 1316 unique public_transport points.
# Downloading education data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 957 unique education points.
# Downloading govt_office data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 145 unique govt_office points.
# Downloading highway data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 8499 unique highway points.
# Downloading mall data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Error downloading amenity data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785) on attempt 1: Expecting value: line 1 column 1 (char 0)
# Found 23 unique mall points.
# Downloading park data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 528 unique park points.
# Downloading airport data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 3 unique airport points.
#
# Processing chunk 90/91...
# Downloading hospital data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 1631 unique hospital points.
# Downloading public_transport data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 1316 unique public_transport points.
# Downloading education data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 957 unique education points.
# Downloading govt_office data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 145 unique govt_office points.
# Downloading highway data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 8499 unique highway points.
# Downloading mall data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 23 unique mall points.
# Downloading park data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 528 unique park points.
# Downloading airport data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 3 unique airport points.
#
# Processing chunk 91/91...
# Downloading hospital data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 1631 unique hospital points.
# Downloading public_transport data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 1316 unique public_transport points.
# Downloading education data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 957 unique education points.
# Downloading govt_office data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 145 unique govt_office points.
# Downloading highway data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 8499 unique highway points.
# Downloading mall data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 23 unique mall points.
# Downloading park data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 528 unique park points.
# Downloading airport data for bbox (12.605, 79.87489000000001, 13.245888802408372, 80.39881785)...
# Found 3 unique airport points.
# All chunks processed and combined results saved.

# %%
import os
import json
import pandas as pd

# Initialize an empty list to store data
data_list = []

# Loop through all JSON files in the current directory
for i in range(1, 92):  # Since you have 91 files
    file_name = f"results_chunk_{i}.json"  # File naming pattern
    
    try:
        with open(file_name, "r", encoding="utf-8") as file:
            data = json.load(file)  # Load JSON file
            if isinstance(data, list):
                data_list.extend(data)  # Append list of data
            else:
                data_list.append(data)  # Append single JSON object
    except Exception as e:
        print(f"Error reading {file_name}: {e}")

# Convert list to DataFrame
df = pd.DataFrame(data_list)

# Save DataFrame to CSV in the same folder
df.to_csv("merged_output.csv", index=False, encoding="utf-8")

print("Merged CSV saved as merged_output.csv")
# Out:
# Merged CSV saved as merged_output.csv
